# %%
import numpy as np
import random
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import math
import scipy.stats as st
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt 
import numpy as np 
import copy
n=5
nn=5
divide_number=1000;
object_number=1.0
batch_size=16
width=0.001
width1=0.0001

# %%
def distribution1(i):
    x=0;
    #x=np.random.uniform(0, 1, size=1);
    #R=np.random.randint(2);
    if (i==0):
        x=np.random.normal(0.5, 0.1, size=1);
    elif(i==1):
        x=np.random.normal(0.4, 0.1, size=1);
    elif(i==2):
        x=np.random.normal(0.3, 0.1, size=1);
    elif(i==3):
        x=np.random.normal(0.2, 0.1, size=1);
    else:
        x=np.random.normal(0.1, 0.1, size=1);
    if(x<=0):
        x=0;
    return x;

def distribution():
    list_temp=np.random.rand(nn);
    for ii in range(len(list_temp)):
        list_temp[ii]=distribution1(ii)
    list_temp=np.array(list_temp)
    #list_temp=sorted(list_temp,reverse=1);
    return list_temp;
print(distribution())
# Out:
# [0.46642401 0.37076977 0.28091525 0.36033032 0.06069063]

# %%
possible = np.zeros((n,divide_number+1), dtype=np.double)
for j in range(0,n):
    for i in range(100000):#100000
        x=distribution1(j%5)*divide_number
        temp=int(x)
        #print(o,temp)
        if(temp>divide_number):
            temp=divide_number
        possible[j][temp]+=1/100000;

# %%
P = np.zeros((n,divide_number+1), dtype=np.double)
for j in range(0,n):
    P[j][0]=possible[j][0]
    for i in range(1,divide_number+1):
        P[j][i]=P[j][i-1]+possible[j][i];
print(P)
# Out:
# [[0.0000e+00 0.0000e+00 0.0000e+00 ... 1.0000e+00 1.0000e+00 1.0000e+00]
#  [1.0000e-05 1.0000e-05 1.0000e-05 ... 1.0000e+00 1.0000e+00 1.0000e+00]
#  [1.4200e-03 1.4800e-03 1.5500e-03 ... 1.0000e+00 1.0000e+00 1.0000e+00]
#  [2.3230e-02 2.3850e-02 2.4490e-02 ... 1.0000e+00 1.0000e+00 1.0000e+00]
#  [1.5954e-01 1.6183e-01 1.6439e-01 ... 1.0000e+00 1.0000e+00 1.0000e+00]]

# %%
dp = np.zeros(((nn+2), (nn+2), divide_number+1), dtype=np.double)
record_dp = np.zeros(((nn+2), (nn+2), divide_number+1), dtype=np.double)
for yes in range(0,nn+1):
    for i in range(0,divide_number+1):
        dp[1][yes][i]=(1.0-P[nn-1][i])*(0.0)+P[nn-1][i]*(yes+1.0);
        record_dp[1][yes][i]=i;

# %%
for i in range(2,nn+1):
    for yes in range(0,nn+1):
        for j in range(divide_number+1):
            min_num=99999;
            for o in range(0,j+1):
                if( min_num>(1.0-P[nn-i][o])*dp[i-1][yes+1][j-o]+P[nn-i][o]*(n)):
                    record_dp[i][yes][j]=o;
                    min_num=(1.0-P[nn-i][o])*dp[i-1][yes+1][j-o]+P[nn-i][o]*(n)
                #min_num=min(min_num,(1.0-P[o])*dp[i-1][yes+1][j-o]+
                #            P[o]*(dp[i-1][yes][j]+1));
                
                #print(i,yes,j,o,(divide_number-o)/divide_number*dp[i-1][yes+1][j-o]+
                #            (o)/divide_number*(dp[i-1][yes][j]+1));
            dp[i][yes][j]=min_num;
        dp[i][yes][0]=0;
        record_dp[i][yes][0]=0

# %%
print(dp[nn][0][divide_number]);
print(record_dp[nn][0][divide_number]);
print(temp)
# Out:
# 2.503531528124924
# 398.0
# 234

# %%
def plan_dp(temp):
    #print(temp)
    remain=divide_number
    yes=0;
    ans =0;
    o_list=[];
    remain_list=[];
    for i in range(nn,0,-1):
        o=record_dp[i][yes][remain]
        #print(o,remain)
        o_list.append(o)
        remain_list.append(remain);
        if(o<temp[nn-i]):
            remain-=int(o);
            
            yes+=1;
        elif (remain>0):
            ans+=1;
            return nn,o_list;
    if(remain<=0):
        return ans,o_list;
    else:
        return nn,o_list;

# %%
ans_list=[];
for i in range(10000):
    temp=distribution()*divide_number   
    ans_list.append(plan_dp(temp)[0]);
    #print(plan_dp(temp)[0])
print(sum(ans_list)/len(ans_list))
# Out:
# 2.0729

# %%
#Cost Sharing
def cost_sharing(test):
    kk=100;
    total_delay1=0;
    for k in range(nn,0,-1):
        count=0;
        delay=0;
        for item in test:
            if(item>=1.0/k):
                count+=1;
            else:
                delay+=1;
        if(count>=k):
            total_delay1+=delay;
            break;
        if(k<=1):
            #print(test);
            total_delay1+=nn;
    return total_delay1;

def cost_sharing_label(test):
    kk=100;
    total_delay1=0;
    temp=[]
    for item in test:
        if(item!=-1):
            temp.append(item);
    for k in range(nn,0,-1):
        count=0;
        delay=0;
        for item in test:
            if(item>=1.0/k):
                count+=1;
            else:
                delay+=1;
        if(count>=k-1):
            return 1.0/k
            break;


total_delay_cost=0;
test_number_cost=10000
for i in range(test_number_cost):
    test=distribution();
    kk=100;
    for k in range(nn,0,-1):
        count=0;
        delay=0;
        for item in test:
            if(item>=1.0/k):
                count+=1;
            else:
                delay+=1;
        if(count>=k):
            total_delay_cost+=delay;
            break;
        if(k<=1):
            #print(test);
            total_delay_cost+=nn;
            

print(total_delay_cost/test_number_cost);
# Out:
# 3.3011

# %%
#print(trainingdata)

import tensorflow as tf
#导入TensorFlow工具包并简称为tf
 
from numpy.random import RandomState
#导入numpy工具包，生成模拟数据集
keep_prob=1
tensor_number=200
w1 = tf.Variable(tf.truncated_normal([n,tensor_number],stddev=0.1))
w2 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w3 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w4 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w5 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w6 = tf.Variable(tf.truncated_normal([tensor_number,n],stddev=0.1))


biases1 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases2 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases3 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases4 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases5 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases6 = tf.Variable(tf.zeros([1,n])+0.01)




lr1 = tf.Variable(0.00000001,dtype=tf.float32)
lr2 = tf.Variable(0.0000001,dtype=tf.float32)
#分别定义一二层和二三层之间的网络参数，标准差为1，随机产生的数保持一致

with tf.name_scope('input'):
    x = tf.placeholder(tf.float32,shape=(None,n),name='x-input1')
    xx = tf.placeholder(tf.float32,shape=(None,n),name='x-input2')
    y = tf.placeholder(tf.float32,shape=(None,n),name='y-input1')

    

#定义神经网络前向传播过程
# Out:
# WARNING:tensorflow:From D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#输入为两个维度，即两个特征，输出为一个标签,声明数据类型float32，None即一个batch大小
#y_是真实的标签

xor0=tf.sigmoid((1e3-x) / 0.00001)

x1_1 = tf.nn.dropout(tf.nn.relu(tf.matmul(xor0,w1))+biases1,keep_prob)
x1_2 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_1,w2))+biases2,keep_prob)
x1_3 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_2,w3))+biases3,keep_prob)
x1_4 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_3,w4))+biases4,keep_prob)
x1_5 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_4,w5))+biases5,keep_prob)
#y1_1  = tf.nn.l2_normalize(tf.nn.dropout(tf.nn.relu(tf.matmul(x1_5,w61)+biases61),keep_prob))
y1_1 = tf.nn.softmax((tf.nn.relu(tf.matmul(x1_5,w6))+biases6))
xor1 = tf.sigmoid((x+0.001-y1_1) / width)
# Out:
# WARNING:tensorflow:From <ipython-input-12-93e042855af8>:6: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
x0_1 = tf.nn.dropout(tf.nn.relu(tf.matmul(xx,w1))+biases1,keep_prob)
x0_2 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_1,w2))+biases2,keep_prob)
x0_3 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_2,w3))+biases3,keep_prob)
x0_4 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_3,w4))+biases4,keep_prob)
x0_5 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_4,w5))+biases5,keep_prob)
#y1_1  = tf.nn.l2_normalize(tf.nn.dropout(tf.nn.relu(tf.matmul(x1_5,w61)+biases61),keep_prob))
y0_1 = tf.nn.softmax((tf.nn.relu(tf.matmul(x0_5,w6))+biases6))

# %%
offer= y1_1 * xor1

# %%
possible=1.0-offer
delay = tf.reduce_sum(offer,reduction_indices=1)

# %%
output_payment = tf.reduce_sum(offer,reduction_indices=1)
delta = tf.sigmoid((output_payment+0.001-1.0) / width1)
tf_delay = delta * tf.reduce_sum((1.0-xor1),reduction_indices=1) + (1.0 - delta) * n;

# %%
#定义损失函数和反向传播算法

loss= 1.0*(tf.reduce_sum(tf_delay))
#loss= tf.reduce_sum(x5_1)
loss_dp= 1.0*(tf.reduce_sum(tf.square(y0_1-y)))

train_step1=tf.train.AdamOptimizer(lr1).minimize(loss)
train_step2=tf.train.GradientDescentOptimizer(lr2).minimize(loss)
train_step3=tf.train.AdadeltaOptimizer(lr1).minimize(loss)
train_step4=tf.train.AdamOptimizer(lr1).minimize(loss_dp)
#train_step4=tf.train.AdagradDAOptimizer(lr2).minimize(loss)
print(loss)
# Out:
# WARNING:tensorflow:From D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Tensor("mul_3:0", shape=(), dtype=float32)

# %%
saver = tf.train.Saver()
#创建会话来运行TensorFlow程序
sess = tf.Session()

init_op = tf.global_variables_initializer()
sess.run(init_op)
writer=tf.summary.FileWriter('logs/',sess.graph)

# %%
def run_appen(list_x):
    x1=list_x[0];
    x2=list_x[1];
    x3=list_x[2];
    x4=list_x[3];
    x5=list_x[4];
    ans,S=plan_dp([x1*divide_number,x2*divide_number,x3*divide_number,
                  x4*divide_number,x5*divide_number]);
    #print(S[0]/divide_number)
    SS=copy.deepcopy(S);
    if(S[0]/divide_number>=x1):
        SS[0]=1;
    else:
        SS[0]=0;
    if(S[1]/divide_number>=x2):
        SS[1]=1;
    else:
        SS[1]=0;
    if(S[2]/divide_number>=x3):
        SS[2]=1;
    else:
        SS[2]=0;
    if(S[3]/divide_number>=x4):
        SS[3]=1;
    else:
        SS[3]=0;
    if(S[4]/divide_number>=x5):
        SS[4]=1;
    else:
        SS[4]=0;
    trainingdata1.append(SS)
    trainingdata.append(list_x)
    #traininglabel1.append([cost_sharing_label(test)])
    traininglabel.append([S[0]/divide_number,
                          S[1]/divide_number,S[2]/divide_number,S[3]/divide_number,S[4]/divide_number])
def readdata():
    for i in range(50000):#50000):
        list_x=distribution();
        newX.append(list_x)
    for i in range(len(newX)):
        run_appen(newX[i]);
        
                            
newX=[];
trainingdata1=[];
trainingdata=[];
traininglabel=[];
def produce_training_data():
    newX=[];
    trainingdata=[];
    S=1.0
    readdata();

produce_training_data();
np.set_printoptions(precision=4, suppress=True)

# %%
dataset_size=len(trainingdata)
j1=1
j2=2
print(trainingdata[j1:j2])
print(sess.run(loss,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(x,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(xor1,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(offer,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
# Out:
# [array([0.6116, 0.4948, 0.1885, 0.4202, 0.0841])]
# 5.0
# [[0.6116 0.4948 0.1885 0.4202 0.0841]]
# [[1. 1. 0. 1. 0.]]
# [[0.1841 0.2209 0.     0.1841 0.    ]]

# %%
print(sess.run(y1_1,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )


print(sess.run(xor1,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(offer,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
# Out:
# [[0.1841 0.2209 0.2268 0.1841 0.1841]]
# [[1. 1. 0. 1. 0.]]
# [[0.1841 0.2209 0.     0.1841 0.    ]]

# %%
save_path = saver.restore(sess, "Tensorflow-5NN-1/1.ckpt")
STEPS = 20001
#设置训练的轮数
flag=0;
training=1;
for i in range(STEPS):

    	#通过选取的样本训练神经网络并更新参数
    if i%500 == 0:
        sess.run(tf.assign(lr1,0.00001*(0.99**(i/1000))))
        sess.run(tf.assign(lr2,0.000001*(0.99**(i/1000))))
        loss_value=0;
        if i%500 == 0:
            for ii in range(10,30):
                #produce_training_data();
                j1=(ii-1)*batch_size
                j2=ii*batch_size
                loss_value += sess.run(loss,feed_dict={
                x:trainingdata[j1:j2]
                 })
            print("After %d training step(s),loss on data is %g" % (i,loss_value/(j2-j1)))
    if i%10000 == -100:
        if((i/100)%3==0):
            flag=0
        elif((i/100)%3==1):
            flag=1
        else:
            flag=1#flag=2

    randomi = random.randint(0,200000);
    start = (randomi) % dataset_size
    end = min(start+batch_size,dataset_size)
    if(flag==0):
        #sess.run(train_step4,feed_dict={x:trainingdata[j1:j2],xx:trainingdata1[j1:j2],y:traininglabel[j1:j2]})                                                                                                                
        sess.run(train_step1,feed_dict={x:trainingdata[j1:j2]})
    elif(flag==1):
        sess.run(train_step2,feed_dict={
                x:trainingdata[j1:j2]
        })
    else:
        sess.run(train_step3,feed_dict={
                x:trainingdata[j1:j2]
        })

    

save_path = saver.save(sess, "Tensorflow-5NN-1/1.ckpt")
# Out:
# WARNING:tensorflow:From D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Tensorflow-5NN-1/1.ckpt
# After 0 training step(s),loss on data is 92.9026
# After 500 training step(s),loss on data is 89.8735
# After 1000 training step(s),loss on data is 89.8735
# After 1500 training step(s),loss on data is 89.8735
# After 2000 training step(s),loss on data is 89.8735
# After 2500 training step(s),loss on data is 89.8735
# After 3000 training step(s),loss on data is 89.8735
# After 3500 training step(s),loss on data is 89.8735
# After 4000 training step(s),loss on data is 89.8735
# After 4500 training step(s),loss on data is 89.8735
# After 5000 training step(s),loss on data is 89.8735
# After 5500 training step(s),loss on data is 89.8735
# After 6000 training step(s),loss on data is 89.8735
# After 6500 training step(s),loss on data is 89.8735
# After 7000 training step(s),loss on data is 89.8735
# After 7500 training step(s),loss on data is 89.8735
# After 8000 training step(s),loss on data is 89.8735
# After 8500 training step(s),loss on data is 89.8735
# After 9000 training step(s),loss on data is 89.8735
# After 9500 training step(s),loss on data is 89.8735
# After 10000 training step(s),loss on data is 89.8735
# After 10500 training step(s),loss on data is 89.8735
# After 11000 training step(s),loss on data is 89.8735
# After 11500 training step(s),loss on data is 89.8735
# After 12000 training step(s),loss on data is 89.8735
# After 12500 training step(s),loss on data is 89.8735
# After 13000 training step(s),loss on data is 89.8735
# After 13500 training step(s),loss on data is 89.8735
# After 14000 training step(s),loss on data is 89.8735
# After 14500 training step(s),loss on data is 89.8735
# After 15000 training step(s),loss on data is 89.8735
# After 15500 training step(s),loss on data is 89.8735
# After 16000 training step(s),loss on data is 89.8735
# After 16500 training step(s),loss on data is 89.8735
# After 17000 training step(s),loss on data is 89.8735
# After 17500 training step(s),loss on data is 89.8735
# After 18000 training step(s),loss on data is 89.8735
# After 18500 training step(s),loss on data is 89.8735
# After 19000 training step(s),loss on data is 89.8735
# After 19500 training step(s),loss on data is 89.8735
# After 20000 training step(s),loss on data is 89.8735

# %%
fig = plt.figure()
batch_size = 1

# %%
global list_payment
list_payment=[];
def judgement(list_x):
    delay=sess.run(tf_delay,feed_dict={x:[list_x]})
    ans = sess.run(output_payment,feed_dict={x:[list_x]})
    #print(delay,ans)
    list_payment.append(ans);
    return delay
def judgement_detail(list_x):
    global list_payment
    offerxor1= sess.run(xor1,feed_dict={x:[list_x]})
    #offerxor2= sess.run(xor2,feed_dict={x:[list_x]})
    #offerxor3= sess.run(xor3,feed_dict={x:[list_x]})
    #offerxor4= sess.run(xor4,feed_dict={x:[list_x]})
    #offerxor5= sess.run(xor5,feed_dict={x:[list_x]})
    Y1= sess.run(y1_1,feed_dict={x:[list_x]})
    #Y2= sess.run(y2_1,feed_dict={x:[list_x]})
    #Y3= sess.run(y3_1,feed_dict={x:[list_x]})
    #Y4= sess.run(y4_1,feed_dict={x:[list_x]})
    #Y5= sess.run(y5_1,feed_dict={x:[list_x]})
    offer_= sess.run(offer,feed_dict={x:[list_x]})
    payment=sess.run(output_payment,feed_dict={x:[list_x]})

    delay=sess.run(tf_delay,feed_dict={x:[list_x]})
    np.set_printoptions(precision=4, suppress=True)
    print('bid:            ',list_x)
    print('Y1:             ',Y1[0])
    print('xor1:           ',offerxor1[0])
    #print('Y2:             ',Y2[0])
    #print('xor2:           ',offerxor2[0])
    #print('Y3:             ',Y3[0])
    #print('xor3:           ',offerxor3[0])
    #print('Y4:             ',Y4[0])
    #print('xor4:           ',offerxor4[0])
    #print('Y5:             ',Y5[0])
    #print('xor5:           ',offerxor5[0])
    print('offer:          ',offer_[0])
    print('payment:        ',payment)
    print('delay:          ',delay,"\n")
    
    return delay

# %%
test_number=10000
 #打印出训练之后神经网络参数的值

mi=10000000;
ma=0;
sum_list=[];
ans_list=[];
for i1 in range(test_number):
    list_x=distribution()
    #print(list_x)
    sum_all =judgement(list_x);
    mi= min(sum_all,mi);
    ma= max(sum_all,ma);
    sum_list.append(sum_all)
    if(i1<=100):
        sum_all =judgement_detail(list_x);
        print("NN: ",sum_all," cost-sharing: ",cost_sharing(list_x)," dp: ",plan_dp(list_x*divide_number)[0])
        print("dp details:",plan_dp(list_x*divide_number)[1])
        print("***************\n")
# Out:
# bid:             [0.2967 0.2409 0.2006 0.1368 0.2041]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.9956 0.     0.9998]
# offer:           [0.2161 0.1998 0.1953 0.     0.1967]
# payment:         [0.8079]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 439.0, 485.0, 1000.0]
# ***************
#
# bid:             [0.6066 0.29   0.1974 0.     0.0395]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.9023 0.     0.    ]
# offer:           [0.2161 0.1998 0.177  0.     0.    ]
# payment:         [0.5929]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.5069 0.4657 0.3841 0.1324 0.1348]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.51   0.2288 0.4007 0.2266 0.0164]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 195.0, 96.0]
# ***************
#
# bid:             [0.6002 0.3761 0.324  0.128  0.0618]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5188 0.314  0.1938 0.1249 0.2198]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.1984 0.     1.    ]
# offer:           [0.2161 0.1998 0.0389 0.     0.1968]
# payment:         [0.6516]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.5215 0.4466 0.1831 0.0114 0.0825]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2161 0.1998 0.     0.     0.    ]
# payment:         [0.4159]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.4955 0.5056 0.2029 0.0855 0.1133]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.9996 0.     0.    ]
# offer:           [0.2161 0.1998 0.1961 0.     0.    ]
# payment:         [0.612]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  1
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.3421 0.5096 0.2094 0.2304 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
#
# bid:             [0.7543 0.3248 0.3914 0.2003 0.0492]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5338 0.5144 0.301  0.0432 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  5
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.5169 0.2779 0.2858 0.     0.0184]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.5142 0.4969 0.3333 0.2458 0.2143]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5242 0.3588 0.4046 0.3051 0.174 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4059 0.4465 0.2941 0.1239 0.0853]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4653 0.4265 0.3536 0.209  0.1458]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.717  0.4916 0.3085 0.4603 0.0601]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3475 0.2554 0.1718 0.1115 0.1548]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2161 0.1998 0.     0.     0.    ]
# payment:         [0.4159]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 439.0, 485.0, 1000.0]
# ***************
#
# bid:             [0.5507 0.4504 0.3305 0.1411 0.1294]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4587 0.4863 0.2325 0.1751 0.1464]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.6255 0.3182 0.487  0.2296 0.1535]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4306 0.204  0.1901 0.1587 0.19  ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     0.9942 0.0063 0.     0.0032]
# offer:           [0.2161 0.1987 0.0012 0.     0.0006]
# payment:         [0.4166]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.5125 0.3035 0.3722 0.1455 0.1152]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.62   0.2087 0.1409 0.4699 0.2544]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     0.9999 0.     1.     1.    ]
# offer:           [0.2161 0.1998 0.     0.1912 0.1968]
# payment:         [0.8038]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  2
# dp details: [398.0, 298.0, 311.0, 350.0, 252.0]
# ***************
#
# bid:             [0.6683 0.3653 0.1832 0.0811 0.0313]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2161 0.1998 0.     0.     0.    ]
# payment:         [0.4159]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.3851 0.5175 0.399  0.2064 0.0148]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [398.0, 410.0, 305.0, 195.0, 90.0]
# ***************
#
# bid:             [0.5318 0.5062 0.4444 0.1114 0.0932]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.6035 0.5503 0.275  0.2524 0.0053]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.6291 0.1958 0.2997 0.0311 0.0594]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     0.0451 1.     0.     0.    ]
# offer:           [0.2161 0.009  0.1962 0.     0.    ]
# payment:         [0.4213]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.5037 0.3121 0.1636 0.2356 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 1. 0.]
# offer:           [0.2161 0.1998 0.     0.1912 0.    ]
# payment:         [0.6071]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 99.0]
# ***************
#
# bid:             [0.4179 0.3628 0.1237 0.2013 0.2066]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 1. 1.]
# offer:           [0.2161 0.1998 0.     0.1912 0.1968]
# payment:         [0.8038]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.513  0.2545 0.337  0.3266 0.1264]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [398.0, 298.0, 311.0, 195.0, 96.0]
# ***************
#
# bid:             [0.3372 0.5006 0.272  0.1608 0.2222]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2161 0.1998 0.1962 0.     0.1968]
# payment:         [0.8088]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
#
# bid:             [0.5581 0.3002 0.4948 0.2957 0.221 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3756 0.5471 0.3973 0.2419 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [398.0, 410.0, 305.0, 195.0, 90.0]
# ***************
#
# bid:             [0.5205 0.1778 0.118  0.1345 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 0. 0. 0. 0.]
# offer:           [0.2161 0.     0.     0.     0.    ]
# payment:         [0.2161]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.6262 0.3577 0.3203 0.2525 0.1774]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.434  0.5838 0.3881 0.221  0.2485]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5646 0.3322 0.2666 0.1488 0.1194]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5455 0.3227 0.2396 0.     0.1855]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  1
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.5835 0.595  0.3633 0.1308 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5035 0.4273 0.3984 0.125  0.0875]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3803 0.5469 0.4815 0.0873 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [398.0, 410.0, 305.0, 195.0, 285.0]
# ***************
#
# bid:             [0.5808 0.4005 0.285  0.2501 0.095 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5524 0.4563 0.1975 0.2871 0.2517]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.9099 1.     1.    ]
# offer:           [0.2161 0.1998 0.1785 0.1912 0.1968]
# payment:         [0.9823]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [398.0, 298.0, 202.0, 205.0, 99.0]
# ***************
#
# bid:             [0.6175 0.3096 0.2809 0.2218 0.042 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4757 0.3619 0.25   0.3723 0.018 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4432 0.5515 0.444  0.1149 0.2055]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     1.     0.     0.9999]
# offer:           [0.2161 0.1998 0.1962 0.     0.1968]
# payment:         [0.8088]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4674 0.4024 0.3783 0.2297 0.082 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3586 0.342  0.0096 0.1166 0.0634]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2161 0.1998 0.     0.     0.    ]
# payment:         [0.4159]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 439.0, 485.0, 1000.0]
# ***************
#
# bid:             [0.5522 0.4613 0.4115 0.2992 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5967 0.3578 0.3868 0.0362 0.1064]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.4655 0.4316 0.1855 0.3055 0.2383]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.0001 1.     1.    ]
# offer:           [0.2161 0.1998 0.     0.1912 0.1968]
# payment:         [0.8038]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  1
# dp details: [398.0, 298.0, 202.0, 205.0, 99.0]
# ***************
#
# bid:             [0.5235 0.3386 0.3269 0.1453 0.0039]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.6039 0.4081 0.5411 0.     0.0634]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.3475 0.4149 0.1462 0.3244 0.3264]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 1. 1.]
# offer:           [0.2161 0.1998 0.     0.1912 0.1968]
# payment:         [0.8038]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
# bid:             [0.2573 0.4516 0.2189 0.     0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
#
# bid:             [0.3811 0.3327 0.3295 0.2275 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 439.0, 485.0, 1000.0]
# ***************
#
# bid:             [0.5329 0.3249 0.1482 0.1666 0.0821]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2161 0.1998 0.     0.     0.    ]
# payment:         [0.4159]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.4413 0.2194 0.3847 0.2272 0.3013]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [398.0, 298.0, 311.0, 195.0, 96.0]
# ***************
#
# bid:             [0.5739 0.3295 0.3099 0.3136 0.0086]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3706 0.4194 0.1282 0.191  0.0565]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.     0.7006 0.    ]
# offer:           [0.2161 0.1998 0.     0.1339 0.    ]
# payment:         [0.5498]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
#
# bid:             [0.4409 0.4676 0.2923 0.3974 0.0631]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5448 0.1741 0.332  0.1169 0.0458]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 0. 1. 0. 0.]
# offer:           [0.2161 0.     0.1962 0.     0.    ]
# payment:         [0.4123]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 195.0, 291.0]
# ***************
#
# bid:             [0.3751 0.4403 0.4173 0.0734 0.1244]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [398.0, 410.0, 305.0, 195.0, 285.0]
# ***************
#
# bid:             [0.4461 0.2151 0.1651 0.2626 0.1449]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 1. 0.]
# offer:           [0.2161 0.1998 0.     0.1912 0.    ]
# payment:         [0.6071]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.5412 0.3905 0.3761 0.2766 0.2129]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4364 0.4966 0.3549 0.3837 0.1622]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4945 0.3584 0.3365 0.1296 0.0129]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4553 0.5598 0.2291 0.3176 0.1464]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4323 0.4222 0.1909 0.0364 0.2831]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.0145 0.     1.    ]
# offer:           [0.2161 0.1998 0.0029 0.     0.1968]
# payment:         [0.6155]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.435  0.2701 0.3567 0.2263 0.1949]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.    1.    1.    1.    0.294]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.0579]
# payment:         [0.8611]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  1
# dp details: [398.0, 298.0, 311.0, 195.0, 96.0]
# ***************
#
# bid:             [0.5363 0.3063 0.1832 0.0765 0.2142]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 1.]
# offer:           [0.2161 0.1998 0.     0.     0.1968]
# payment:         [0.6127]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.5746 0.3147 0.2003 0.1911 0.1602]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.994  0.7147 0.    ]
# offer:           [0.2161 0.1998 0.195  0.1366 0.    ]
# payment:         [0.7475]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.4729 0.2856 0.3256 0.2656 0.1262]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [398.0, 298.0, 311.0, 195.0, 96.0]
# ***************
#
# bid:             [0.4918 0.4046 0.321  0.2166 0.1017]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4123 0.253  0.2738 0.098  0.0891]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.4974 0.493  0.213  0.1235 0.1064]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5725 0.5185 0.1754 0.1556 0.0631]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2161 0.1998 0.     0.     0.    ]
# payment:         [0.4159]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  5
# dp details: [398.0, 298.0, 202.0, 205.0, 304.0]
# ***************
#
# bid:             [0.7087 0.2957 0.296  0.0552 0.1059]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.4045 0.4128 0.3366 0.2414 0.0908]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3399 0.2837 0.355  0.3991 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  5
# dp details: [398.0, 410.0, 439.0, 485.0, 1000.0]
# ***************
#
# bid:             [0.2714 0.3711 0.4391 0.2676 0.1648]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  5
# dp details: [398.0, 410.0, 439.0, 325.0, 561.0]
# ***************
#
# bid:             [0.4623 0.4518 0.2114 0.0919 0.0176]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.7259 0.2336 0.2749 0.1139 0.1788]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.7246 0.3383 0.4421 0.2399 0.0233]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4324 0.3179 0.3148 0.073  0.0223]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.6151 0.5493 0.1683 0.2302 0.161 ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 0. 1. 0.]
# offer:           [0.2161 0.1998 0.     0.1912 0.    ]
# payment:         [0.6071]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  1
# dp details: [398.0, 298.0, 202.0, 205.0, 99.0]
# ***************
#
# bid:             [0.5002 0.5551 0.3276 0.1518 0.0605]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4323 0.5358 0.38   0.3421 0.2129]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.5097 0.2945 0.2745 0.1625 0.1526]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 350.0, 602.0]
# ***************
#
# bid:             [0.4303 0.2355 0.3992 0.0189 0.2096]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2161 0.1998 0.1962 0.     0.1968]
# payment:         [0.8088]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 311.0, 195.0, 291.0]
# ***************
#
# bid:             [0.504  0.3169 0.283  0.0622 0.    ]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.4574 0.5254 0.3335 0.1662 0.2811]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2161 0.1998 0.1962 0.     0.1968]
# payment:         [0.8088]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.4862 0.5361 0.2192 0.2167 0.2034]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     1.     1.     0.9995]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1967]
# payment:         [0.9999]
# delay:           [0.0011]
#
# NN:  [0.0011]  cost-sharing:  0  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3816 0.4844 0.2535 0.269  0.2612]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.1968]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
#
# bid:             [0.4543 0.4123 0.5234 0.1766 0.0856]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2161 0.1998 0.1962 0.     0.    ]
# payment:         [0.6121]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************
#
# bid:             [0.3931 0.6567 0.3026 0.0461 0.2401]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2161 0.1998 0.1962 0.     0.1968]
# payment:         [0.8088]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [398.0, 410.0, 305.0, 348.0, 590.0]
# ***************
#
# bid:             [0.3842 0.36   0.4684 0.1718 0.2121]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2161 0.1998 0.1962 0.     0.1968]
# payment:         [0.8088]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [398.0, 410.0, 439.0, 325.0, 561.0]
# ***************
#
# bid:             [0.6171 0.5487 0.2025 0.0237 0.1512]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1.     1.     0.9994 0.     0.    ]
# offer:           [0.2161 0.1998 0.196  0.     0.    ]
# payment:         [0.6119]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  1
# dp details: [398.0, 298.0, 202.0, 102.0, 102.0]
# ***************
#
# bid:             [0.4219 0.5806 0.257  0.2079 0.0893]
# Y1:              [0.2161 0.1998 0.1962 0.1912 0.1968]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2161 0.1998 0.1962 0.1912 0.    ]
# payment:         [0.8032]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  0
# dp details: [398.0, 298.0, 202.0, 102.0, 0.0]
# ***************

# %%
print(mi, ma)
print(sum(sum_list)/len(sum_list))
# Out:
# [0.0002] [5.]
# [4.6785]

# %%
data=np.array(sum_list)
data=data.reshape(-1)
#print(data.reshape(-1))

# %%
plt.hist(data,bins=300)
plt.show()

# %%
for i in range(len(sum_list)):
    sum_list[i]=np.round(sum_list[i]);
print(mi, ma)
print("NN:           ",sum(sum_list)/len(sum_list))
# Out:
# [0.0002] [5.]
# NN:            [4.6784]

# %%
print("cost-sharing: ",total_delay_cost/test_number_cost);
# Out:
# cost-sharing:  3.3011

# %%
print("dp:           ",dp[nn][0][divide_number]);
# Out:
# dp:            2.503531528124924

# %%
print(sum(list_payment)/len(list_payment))
# Out:
# [0.7108]

# %% [markdown]
# ####

# %% [markdown]
# #####
