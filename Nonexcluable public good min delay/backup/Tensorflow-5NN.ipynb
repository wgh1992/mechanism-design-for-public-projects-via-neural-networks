# %%
import numpy as np
import random
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import math
import scipy.stats as st
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt 
import numpy as np 
import copy
n=5
nn=5
divide_number=1000;
object_number=1.0
batch_size=16
width=0.0001
width1=0.0001

# %%
def distribution1(i):
    x=0;
    #x=np.random.uniform(0, 1, size=1);
    #R=np.random.randint(2);
    if (i==0):
        x=np.random.uniform(0, 1, size=1);
    elif(i==1):
        x=np.random.uniform(0, 1, size=1);
    elif(i==2):
        x=np.random.uniform(0, 1, size=1);
    elif(i==3):
        x=np.random.uniform(0, 1, size=1);
    else:
        x=np.random.uniform(0, 1, size=1);
    if(x<=0):
        x=0;
    return x;

def distribution():
    list_temp=np.random.rand(nn);
    for ii in range(len(list_temp)):
        list_temp[ii]=distribution1(ii)
    list_temp=np.array(list_temp)
    #list_temp=sorted(list_temp,reverse=1);
    return list_temp;
print(distribution())
# Out:
# [0.88347262 0.48552929 0.01096651 0.49402741 0.91327725]

# %%
possible = np.zeros((n,divide_number+1), dtype=np.double)
for j in range(0,n):
    for i in range(100000):#100000
        x=distribution1(j%5)*divide_number
        temp=int(x)
        #print(o,temp)
        if(temp>divide_number):
            temp=divide_number
        possible[j][temp]+=1/100000;

# %%
P = np.zeros((n,divide_number+1), dtype=np.double)
for j in range(0,n):
    P[j][0]=possible[j][0]
    for i in range(1,divide_number+1):
        P[j][i]=P[j][i-1]+possible[j][i];
print(P)
# Out:
# [[8.3000e-04 1.7500e-03 2.6600e-03 ... 9.9896e-01 1.0000e+00 1.0000e+00]
#  [1.0300e-03 1.9900e-03 2.9500e-03 ... 9.9887e-01 1.0000e+00 1.0000e+00]
#  [9.7000e-04 1.7800e-03 2.6800e-03 ... 9.9901e-01 1.0000e+00 1.0000e+00]
#  [9.3000e-04 1.9500e-03 2.8500e-03 ... 9.9899e-01 1.0000e+00 1.0000e+00]
#  [1.0400e-03 2.2000e-03 3.2100e-03 ... 9.9893e-01 1.0000e+00 1.0000e+00]]

# %%
dp = np.zeros(((nn+2), (nn+2), divide_number+1), dtype=np.double)
record_dp = np.zeros(((nn+2), (nn+2), divide_number+1), dtype=np.double)
for yes in range(0,nn+1):
    for i in range(0,divide_number+1):
        dp[1][yes][i]=(1.0-P[nn-1][i])*(0.0)+P[nn-1][i]*(yes+1.0);
        record_dp[1][yes][i]=i;

# %%
for i in range(2,nn+1):
    for yes in range(0,nn+1):
        for j in range(divide_number+1):
            min_num=99999;
            for o in range(0,j+1):
                if( min_num>(1.0-P[nn-i][o])*dp[i-1][yes+1][j-o]+P[nn-i][o]*(n)):
                    record_dp[i][yes][j]=o;
                    min_num=(1.0-P[nn-i][o])*dp[i-1][yes+1][j-o]+P[nn-i][o]*(n)
                #min_num=min(min_num,(1.0-P[o])*dp[i-1][yes+1][j-o]+
                #            P[o]*(dp[i-1][yes][j]+1));
                
                #print(i,yes,j,o,(divide_number-o)/divide_number*dp[i-1][yes+1][j-o]+
                #            (o)/divide_number*(dp[i-1][yes][j]+1));
            dp[i][yes][j]=min_num;
        dp[i][yes][0]=0;
        record_dp[i][yes][0]=0

# %%
print(dp[nn][0][divide_number]);
print(record_dp[nn][0][divide_number]);
print(temp)
# Out:
# 1.6223377207976672
# 327.0
# 370

# %%
def plan_dp(temp):
    #print(temp)
    remain=divide_number
    yes=0;
    ans =0;
    o_list=[];
    remain_list=[];
    for i in range(nn,0,-1):
        o=record_dp[i][yes][remain]
        #print(o,remain)
        o_list.append(o)
        remain_list.append(remain);
        if(o<temp[nn-i]):
            remain-=int(o);
            
            yes+=1;
        elif (remain>0):
            ans+=1;
            return nn,o_list;
    if(remain<=0):
        return ans,o_list;
    else:
        return nn,o_list;

# %%
ans_list=[];
for i in range(10000):
    temp=distribution()*divide_number   
    ans_list.append(plan_dp(temp)[0]);
    #print(plan_dp(temp)[0])
print(sum(ans_list)/len(ans_list))
# Out:
# 1.6035

# %%
#Cost Sharing
def cost_sharing(test):
    kk=100;
    total_delay1=0;
    for k in range(nn,0,-1):
        count=0;
        delay=0;
        for item in test:
            if(item>=1.0/k):
                count+=1;
            else:
                delay+=1;
        if(count>=k):
            total_delay1+=delay;
            break;
        if(k<=1):
            #print(test);
            total_delay1+=nn;
    return total_delay1;

def cost_sharing_label(test):
    kk=100;
    total_delay1=0;
    temp=[]
    for item in test:
        if(item!=-1):
            temp.append(item);
    for k in range(nn,0,-1):
        count=0;
        delay=0;
        for item in test:
            if(item>=1.0/k):
                count+=1;
            else:
                delay+=1;
        if(count>=k-1):
            return 1.0/k
            break;


total_delay_cost=0;
test_number_cost=10000
for i in range(test_number_cost):
    test=distribution();
    kk=100;
    for k in range(nn,0,-1):
        count=0;
        delay=0;
        for item in test:
            if(item>=1.0/k):
                count+=1;
            else:
                delay+=1;
        if(count>=k):
            total_delay_cost+=delay;
            break;
        if(k<=1):
            #print(test);
            total_delay_cost+=nn;
            

print(total_delay_cost/test_number_cost);
# Out:
# 1.4131

# %%
#print(trainingdata)

import tensorflow as tf
#导入TensorFlow工具包并简称为tf
 
from numpy.random import RandomState
#导入numpy工具包，生成模拟数据集
keep_prob=1
tensor_number=200
w1 = tf.Variable(tf.truncated_normal([n,tensor_number],stddev=0.1))
w2 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w3 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w4 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w5 = tf.Variable(tf.truncated_normal([tensor_number,tensor_number],stddev=0.1))
w6 = tf.Variable(tf.truncated_normal([tensor_number,n],stddev=0.1))


biases1 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases2 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases3 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases4 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases5 = tf.Variable(tf.zeros([1,tensor_number])+0.01)
biases6 = tf.Variable(tf.zeros([1,n])+0.01)




lr1 = tf.Variable(0.00000001,dtype=tf.float32)
lr2 = tf.Variable(0.0000001,dtype=tf.float32)
#分别定义一二层和二三层之间的网络参数，标准差为1，随机产生的数保持一致

with tf.name_scope('input'):
    x = tf.placeholder(tf.float32,shape=(None,n),name='x-input1')
    xx = tf.placeholder(tf.float32,shape=(None,n),name='x-input2')
    y = tf.placeholder(tf.float32,shape=(None,n),name='y-input1')

    

#定义神经网络前向传播过程
# Out:
# WARNING:tensorflow:From D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#输入为两个维度，即两个特征，输出为一个标签,声明数据类型float32，None即一个batch大小
#y_是真实的标签

xor0=tf.sigmoid((1e3-x) / 0.00001)

x1_1 = tf.nn.dropout(tf.nn.relu(tf.matmul(xor0,w1))+biases1,keep_prob)
x1_2 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_1,w2))+biases2,keep_prob)
x1_3 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_2,w3))+biases3,keep_prob)
x1_4 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_3,w4))+biases4,keep_prob)
x1_5 = tf.nn.dropout(tf.nn.relu(tf.matmul(x1_4,w5))+biases5,keep_prob)
#y1_1  = tf.nn.l2_normalize(tf.nn.dropout(tf.nn.relu(tf.matmul(x1_5,w61)+biases61),keep_prob))
y1_1 = tf.nn.softmax((tf.nn.relu(tf.matmul(x1_5,w6))+biases6))
xor1 = tf.sigmoid((x+0.001-y1_1) / width)
# Out:
# WARNING:tensorflow:From <ipython-input-12-93e042855af8>:6: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
x0_1 = tf.nn.dropout(tf.nn.relu(tf.matmul(xx,w1))+biases1,keep_prob)
x0_2 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_1,w2))+biases2,keep_prob)
x0_3 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_2,w3))+biases3,keep_prob)
x0_4 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_3,w4))+biases4,keep_prob)
x0_5 = tf.nn.dropout(tf.nn.relu(tf.matmul(x0_4,w5))+biases5,keep_prob)
#y1_1  = tf.nn.l2_normalize(tf.nn.dropout(tf.nn.relu(tf.matmul(x1_5,w61)+biases61),keep_prob))
y0_1 = tf.nn.softmax((tf.nn.relu(tf.matmul(x0_5,w6))+biases6))

# %%
offer= y1_1 * xor1

# %%
possible=1.0-offer
delay = tf.reduce_sum(offer,reduction_indices=1)

# %%
output_payment = tf.reduce_sum(offer,reduction_indices=1)
delta = tf.sigmoid((output_payment+0.001-1.0) / width1)
tf_delay = delta * tf.reduce_sum((1.0-xor1),reduction_indices=1) + (1.0 - delta) * n;

# %%
#定义损失函数和反向传播算法

loss= 1.0*(tf.reduce_sum(tf_delay))
#loss= tf.reduce_sum(x5_1)
loss_dp= 1.0*(tf.reduce_sum(tf.square(y0_1-y)))

train_step1=tf.train.AdamOptimizer(lr1).minimize(loss)
train_step2=tf.train.GradientDescentOptimizer(lr2).minimize(loss)
train_step3=tf.train.AdadeltaOptimizer(lr1).minimize(loss)
train_step4=tf.train.AdamOptimizer(lr1).minimize(loss_dp)
#train_step4=tf.train.AdagradDAOptimizer(lr2).minimize(loss)
print(loss)
# Out:
# WARNING:tensorflow:From D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Tensor("mul_3:0", shape=(), dtype=float32)

# %%
saver = tf.train.Saver()
#创建会话来运行TensorFlow程序
sess = tf.Session()

init_op = tf.global_variables_initializer()
sess.run(init_op)
writer=tf.summary.FileWriter('logs/',sess.graph)

# %%
def run_appen(list_x):
    x1=list_x[0];
    x2=list_x[1];
    x3=list_x[2];
    x4=list_x[3];
    x5=list_x[4];
    ans,S=plan_dp([x1*divide_number,x2*divide_number,x3*divide_number,
                  x4*divide_number,x5*divide_number]);
    #print(S[0]/divide_number)
    SS=copy.deepcopy(S);
    if(S[0]/divide_number>=x1):
        SS[0]=1;
    else:
        SS[0]=0;
    if(S[1]/divide_number>=x2):
        SS[1]=1;
    else:
        SS[1]=0;
    if(S[2]/divide_number>=x3):
        SS[2]=1;
    else:
        SS[2]=0;
    if(S[3]/divide_number>=x4):
        SS[3]=1;
    else:
        SS[3]=0;
    if(S[4]/divide_number>=x5):
        SS[4]=1;
    else:
        SS[4]=0;
    trainingdata1.append(SS)
    trainingdata.append(list_x)
    #traininglabel1.append([cost_sharing_label(test)])
    traininglabel.append([S[0]/divide_number,
                          S[1]/divide_number,S[2]/divide_number,S[3]/divide_number,S[4]/divide_number])
def readdata():
    for i in range(50000):#50000):
        list_x=distribution();
        newX.append(list_x)
    for i in range(len(newX)):
        run_appen(newX[i]);
        
                            
newX=[];
trainingdata1=[];
trainingdata=[];
traininglabel=[];
def produce_training_data():
    newX=[];
    trainingdata=[];
    S=1.0
    readdata();

produce_training_data();
np.set_printoptions(precision=4, suppress=True)

# %%
dataset_size=len(trainingdata)
j1=1
j2=2
print(trainingdata[j1:j2])
print(sess.run(loss,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(x,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(xor1,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(offer,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
# Out:
# [array([0.898 , 0.3557, 0.8871, 0.3518, 0.9545])]
# 0.0002270937
# [[0.898  0.3557 0.8871 0.3518 0.9545]]
# [[1. 1. 1. 1. 1.]]
# [[0.1807 0.205  0.2011 0.1859 0.2274]]

# %%
print(sess.run(y1_1,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )


print(sess.run(xor1,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
print(sess.run(offer,feed_dict={
    x:trainingdata[j1:j2]
}
              )
     )
# Out:
# [[0.1807 0.205  0.2011 0.1859 0.2274]]
# [[1. 1. 1. 1. 1.]]
# [[0.1807 0.205  0.2011 0.1859 0.2274]]

# %%
save_path = saver.restore(sess, "Tensorflow-5NN/2.ckpt")
STEPS = 20001
#设置训练的轮数
flag=0;
training=1;
for i in range(STEPS):

    	#通过选取的样本训练神经网络并更新参数
    if i%500 == 0:
        sess.run(tf.assign(lr1,0.00001*(0.99**(i/1000))))
        sess.run(tf.assign(lr2,0.000001*(0.99**(i/1000))))
        loss_value=0;
        if i%500 == 0:
            for ii in range(10,30):
                #produce_training_data();
                j1=(ii-1)*batch_size
                j2=ii*batch_size
                loss_value += sess.run(loss,feed_dict={
                x:trainingdata[j1:j2]
                 })
            print("After %d training step(s),loss on data is %g" % (i,loss_value/(j2-j1)))
    if i%10000 == -100:
        if((i/100)%3==0):
            flag=0
        elif((i/100)%3==1):
            flag=1
        else:
            flag=1#flag=2

    randomi = random.randint(0,200000);
    start = (randomi) % dataset_size
    end = min(start+batch_size,dataset_size)
    if(flag==0):
        #sess.run(train_step4,feed_dict={x:trainingdata[j1:j2],xx:trainingdata1[j1:j2],y:traininglabel[j1:j2]})                                                                                                                
        sess.run(train_step1,feed_dict={x:trainingdata[j1:j2]})
    elif(flag==1):
        sess.run(train_step2,feed_dict={
                x:trainingdata[j1:j2]
        })
    else:
        sess.run(train_step3,feed_dict={
                x:trainingdata[j1:j2]
        })

    

save_path = saver.save(sess, "Tensorflow-5NN/2.ckpt")
# Out:
# WARNING:tensorflow:From D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Tensorflow-5NN/2.ckpt
# After 0 training step(s),loss on data is 69.6889
# After 500 training step(s),loss on data is 69.6889
# After 1000 training step(s),loss on data is 69.6889
# After 1500 training step(s),loss on data is 69.6889
# After 2000 training step(s),loss on data is 69.6889
# After 2500 training step(s),loss on data is 69.6889
# After 3000 training step(s),loss on data is 69.6889
# After 3500 training step(s),loss on data is 69.6889
# After 4000 training step(s),loss on data is 69.6889
# After 4500 training step(s),loss on data is 69.6889
# After 5000 training step(s),loss on data is 69.6889
# After 5500 training step(s),loss on data is 69.6889
# After 6000 training step(s),loss on data is 69.6889
# After 6500 training step(s),loss on data is 69.6889
# After 7000 training step(s),loss on data is 69.6889
# After 7500 training step(s),loss on data is 69.6889
# After 8000 training step(s),loss on data is 69.6889
# After 8500 training step(s),loss on data is 69.6889
# After 9000 training step(s),loss on data is 69.6889
# After 9500 training step(s),loss on data is 69.6889
# After 10000 training step(s),loss on data is 69.6889
# After 10500 training step(s),loss on data is 69.6889
# After 11000 training step(s),loss on data is 69.6889
# After 11500 training step(s),loss on data is 69.6889
# After 12000 training step(s),loss on data is 69.6889
# After 12500 training step(s),loss on data is 69.6889
# After 13000 training step(s),loss on data is 69.6889
# After 13500 training step(s),loss on data is 69.6889
# After 14000 training step(s),loss on data is 69.6889
# After 14500 training step(s),loss on data is 69.6889
# After 15000 training step(s),loss on data is 69.6889
# After 15500 training step(s),loss on data is 69.6889
# After 16000 training step(s),loss on data is 69.6889
# After 16500 training step(s),loss on data is 69.6889
# After 17000 training step(s),loss on data is 69.6889
# After 17500 training step(s),loss on data is 69.6889
# After 18000 training step(s),loss on data is 69.6889
# After 18500 training step(s),loss on data is 69.6889
# After 19000 training step(s),loss on data is 69.6889
# After 19500 training step(s),loss on data is 69.6889
# After 20000 training step(s),loss on data is 69.6889
# After 20500 training step(s),loss on data is 69.6889
# After 21000 training step(s),loss on data is 69.6889
# After 21500 training step(s),loss on data is 69.6889
# After 22000 training step(s),loss on data is 69.6889
# After 22500 training step(s),loss on data is 69.6889
# After 23000 training step(s),loss on data is 69.6889
# After 23500 training step(s),loss on data is 69.6889
# After 24000 training step(s),loss on data is 69.6889
# After 24500 training step(s),loss on data is 69.6889
# After 25000 training step(s),loss on data is 69.6889
# After 25500 training step(s),loss on data is 69.6889
# After 26000 training step(s),loss on data is 69.6889
# After 26500 training step(s),loss on data is 69.6889
# After 27000 training step(s),loss on data is 69.6889
# After 27500 training step(s),loss on data is 69.6889
# After 28000 training step(s),loss on data is 69.6889
# After 28500 training step(s),loss on data is 69.6889
# After 29000 training step(s),loss on data is 69.6889
# After 29500 training step(s),loss on data is 69.6889
# After 30000 training step(s),loss on data is 69.6889
# After 30500 training step(s),loss on data is 69.6889
# After 31000 training step(s),loss on data is 69.6889
# After 31500 training step(s),loss on data is 69.6889
# After 32000 training step(s),loss on data is 69.6889
# After 32500 training step(s),loss on data is 69.6889
# After 33000 training step(s),loss on data is 69.6889
# After 33500 training step(s),loss on data is 69.6889
# After 34000 training step(s),loss on data is 69.6889
# After 34500 training step(s),loss on data is 69.6889
# After 35000 training step(s),loss on data is 69.6889
# After 35500 training step(s),loss on data is 69.6889
# After 36000 training step(s),loss on data is 69.6889
# After 36500 training step(s),loss on data is 69.6889
# After 37000 training step(s),loss on data is 69.6889
# After 37500 training step(s),loss on data is 69.6889
# After 38000 training step(s),loss on data is 69.6889
# After 38500 training step(s),loss on data is 69.6889
# After 39000 training step(s),loss on data is 69.6889
# After 39500 training step(s),loss on data is 69.6889
# After 40000 training step(s),loss on data is 69.6889
# After 40500 training step(s),loss on data is 69.6889
# After 41000 training step(s),loss on data is 69.6889
# After 41500 training step(s),loss on data is 69.6889
# After 42000 training step(s),loss on data is 69.6889
# After 42500 training step(s),loss on data is 69.6889
# After 43000 training step(s),loss on data is 69.6889
# After 43500 training step(s),loss on data is 69.6889
# After 44000 training step(s),loss on data is 69.6889
# After 44500 training step(s),loss on data is 69.6889
# After 45000 training step(s),loss on data is 69.6889
# After 45500 training step(s),loss on data is 69.6889
# After 46000 training step(s),loss on data is 69.6889
# After 46500 training step(s),loss on data is 69.6889
# After 47000 training step(s),loss on data is 69.6889
# After 47500 training step(s),loss on data is 69.6889
# After 48000 training step(s),loss on data is 69.6889
# After 48500 training step(s),loss on data is 69.6889
# After 49000 training step(s),loss on data is 69.6889
# After 49500 training step(s),loss on data is 69.6889
# After 50000 training step(s),loss on data is 69.6889

# %%
fig = plt.figure()
batch_size = 1

# %%
global list_payment
list_payment=[];
def judgement(list_x):
    delay=sess.run(tf_delay,feed_dict={x:[list_x]})
    ans = sess.run(output_payment,feed_dict={x:[list_x]})
    #print(delay,ans)
    list_payment.append(ans);
    return delay
def judgement_detail(list_x):
    global list_payment
    offerxor1= sess.run(xor1,feed_dict={x:[list_x]})
    #offerxor2= sess.run(xor2,feed_dict={x:[list_x]})
    #offerxor3= sess.run(xor3,feed_dict={x:[list_x]})
    #offerxor4= sess.run(xor4,feed_dict={x:[list_x]})
    #offerxor5= sess.run(xor5,feed_dict={x:[list_x]})
    Y1= sess.run(y1_1,feed_dict={x:[list_x]})
    #Y2= sess.run(y2_1,feed_dict={x:[list_x]})
    #Y3= sess.run(y3_1,feed_dict={x:[list_x]})
    #Y4= sess.run(y4_1,feed_dict={x:[list_x]})
    #Y5= sess.run(y5_1,feed_dict={x:[list_x]})
    offer_= sess.run(offer,feed_dict={x:[list_x]})
    payment=sess.run(output_payment,feed_dict={x:[list_x]})

    delay=sess.run(tf_delay,feed_dict={x:[list_x]})
    np.set_printoptions(precision=4, suppress=True)
    print('bid:            ',list_x)
    print('Y1:             ',Y1[0])
    print('xor1:           ',offerxor1[0])
    #print('Y2:             ',Y2[0])
    #print('xor2:           ',offerxor2[0])
    #print('Y3:             ',Y3[0])
    #print('xor3:           ',offerxor3[0])
    #print('Y4:             ',Y4[0])
    #print('xor4:           ',offerxor4[0])
    #print('Y5:             ',Y5[0])
    #print('xor5:           ',offerxor5[0])
    print('offer:          ',offer_[0])
    print('payment:        ',payment)
    print('delay:          ',delay,"\n")
    
    return delay

# %%
test_number=10000
 #打印出训练之后神经网络参数的值

mi=10000000;
ma=0;
sum_list=[];
ans_list=[];
for i1 in range(test_number):
    list_x=distribution()
    #print(list_x)
    sum_all =judgement(list_x);
    mi= min(sum_all,mi);
    ma= max(sum_all,ma);
    sum_list.append(sum_all)
    if(i1<=100):
        sum_all =judgement_detail(list_x);
        print("NN: ",sum_all," cost-sharing: ",cost_sharing(list_x)," dp: ",plan_dp(list_x*divide_number)[0])
        print("dp details:",plan_dp(list_x*divide_number)[1])
        print("***************\n")
# Out:
# bid:             [0.798  0.2506 0.7623 0.0485 0.903 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  2
# dp details: [327.0, 286.0, 354.0, 319.0, 319.0]
# ***************
#
# bid:             [0.6416 0.5752 0.0605 0.0776 0.5316]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 0. 1.]
# offer:           [0.2488 0.2055 0.     0.     0.2019]
# payment:         [0.6561]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.5718 0.542  0.5732 0.5423 0.9133]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.4305 0.4504 0.3356 0.0991 0.0973]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2488 0.2055 0.1378 0.     0.    ]
# payment:         [0.592]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [327.0, 286.0, 251.0, 136.0, 136.0]
# ***************
#
# bid:             [0.0603 0.8566 0.3307 0.3219 0.6793]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  3
# dp details: [327.0, 375.0, 344.0, 424.0, 625.0]
# ***************
#
# bid:             [0.4028 0.4431 0.8301 0.121  0.1857]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2488 0.2055 0.1378 0.     0.    ]
# payment:         [0.592]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 251.0, 136.0, 136.0]
# ***************
#
# bid:             [0.4923 0.5237 0.126  0.3856 0.6534]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 1. 1.]
# offer:           [0.2488 0.2055 0.     0.2061 0.2019]
# payment:         [0.8622]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.5732 0.6361 0.4493 0.0642 0.671 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 251.0, 136.0, 136.0]
# ***************
#
# bid:             [0.4892 0.6344 0.1361 0.1621 0.2645]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1.     1.     0.0009 0.     1.    ]
# offer:           [0.2488 0.2055 0.0001 0.     0.2019]
# payment:         [0.6562]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.0628 0.059  0.8119 0.5717 0.1203]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 0. 1. 1. 0.]
# offer:           [0.     0.     0.1378 0.2061 0.    ]
# payment:         [0.3439]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  2
# dp details: [327.0, 375.0, 456.0, 426.0, 118.0]
# ***************
#
# bid:             [0.5151 0.1276 0.7552 0.7592 0.2503]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.2935 0.0375 0.288  0.5718 0.1288]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 0.]
# offer:           [0.2488 0.     0.1378 0.2061 0.    ]
# payment:         [0.5927]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 456.0, 511.0, 489.0]
# ***************
#
# bid:             [0.8199 0.2415 0.5395 0.7188 0.5074]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.4912 0.3252 0.5216 0.5478 0.2484]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.7796 0.9316 0.5231 0.9426 0.8425]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.5143 0.9188 0.0158 0.6477 0.1581]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 1. 0.]
# offer:           [0.2488 0.2055 0.     0.2061 0.    ]
# payment:         [0.6604]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.8023 0.7309 0.0014 0.1602 0.5747]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 0. 1.]
# offer:           [0.2488 0.2055 0.     0.     0.2019]
# payment:         [0.6561]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.8894 0.5224 0.1982 0.9174 0.7797]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.4976 0.289  0.1167 0.27   0.5687]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 1. 1.]
# offer:           [0.2488 0.2055 0.     0.2061 0.2019]
# payment:         [0.8622]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.8614 0.2722 0.2364 0.5748 0.2045]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.8239 0.6499 0.436  0.169  0.8204]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.5838 0.3597 0.1023 0.9548 0.9113]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 1. 1.]
# offer:           [0.2488 0.2055 0.     0.2061 0.2019]
# payment:         [0.8622]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.7078 0.7557 0.6587 0.7689 0.8003]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.5723 0.6813 0.4176 0.9856 0.9813]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.1141 0.9081 0.3234 0.9553 0.7266]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  2
# dp details: [327.0, 375.0, 344.0, 424.0, 201.0]
# ***************
#
# bid:             [0.9335 0.6958 0.0851 0.1153 0.931 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 0. 1.]
# offer:           [0.2488 0.2055 0.     0.     0.2019]
# payment:         [0.6561]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.1645 0.4635 0.4931 0.0292 0.0601]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 0. 0.]
# offer:           [0.     0.2055 0.1378 0.     0.    ]
# payment:         [0.3432]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 344.0, 281.0, 281.0]
# ***************
#
# bid:             [0.58   0.9014 0.5743 0.491  0.2901]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.2626 0.6467 0.2648 0.8488 0.8507]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  2
# dp details: [327.0, 375.0, 344.0, 424.0, 201.0]
# ***************
#
# bid:             [0.658  0.753  0.8252 0.8424 0.1795]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.686  0.72   0.9108 0.2314 0.3667]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.0009 0.8105 0.4412 0.2442 0.3263]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  2
# dp details: [327.0, 375.0, 344.0, 281.0, 281.0]
# ***************
#
# bid:             [0.1942 0.7651 0.6607 0.7951 0.7597]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 375.0, 344.0, 281.0, 0.0]
# ***************
#
# bid:             [0.3451 0.4453 0.7647 0.9385 0.8687]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.6837 0.6191 0.6684 0.4547 0.6081]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.0011 0.4856 0.012  0.4059 0.6293]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 0. 1. 1.]
# offer:           [0.     0.2055 0.     0.2061 0.2019]
# payment:         [0.6134]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  3
# dp details: [327.0, 375.0, 344.0, 424.0, 625.0]
# ***************
#
# bid:             [0.3621 0.5952 0.6164 0.2534 0.4923]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.7622 0.4374 0.8399 0.5391 0.151 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.9576 0.7904 0.1791 0.9431 0.8866]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.1432 0.8416 0.8447 0.7275 0.0675]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 0.]
# offer:           [0.     0.2055 0.1378 0.2061 0.    ]
# payment:         [0.5493]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 375.0, 344.0, 281.0, 0.0]
# ***************
#
# bid:             [0.5627 0.2744 0.171  0.3757 0.323 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  1  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 673.0]
# ***************
#
# bid:             [0.6098 0.3658 0.7823 0.943  0.8562]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.4021 0.1934 0.4295 0.4282 0.6408]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.6585 0.7504 0.5158 0.4853 0.3492]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.2258 0.6032 0.9345 0.4731 0.2724]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  0  dp:  1
# dp details: [327.0, 375.0, 344.0, 281.0, 0.0]
# ***************
#
# bid:             [0.8313 0.6522 0.1394 0.7979 0.0274]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.3893 0.9955 0.2132 0.508  0.9667]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.5576 0.0469 0.1701 0.6534 0.9364]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.2241 0.8537 0.7764 0.4861 0.9261]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  0  dp:  1
# dp details: [327.0, 375.0, 344.0, 281.0, 0.0]
# ***************
#
# bid:             [0.3926 0.6205 0.1628 0.211  0.4848]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.6057 0.2613 0.1904 0.6126 0.0496]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.2289 0.5329 0.4836 0.0357 0.2947]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 0. 1.]
# offer:           [0.     0.2055 0.1378 0.     0.2019]
# payment:         [0.5451]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  2
# dp details: [327.0, 375.0, 344.0, 281.0, 281.0]
# ***************
#
# bid:             [0.5045 0.4411 0.5293 0.6448 0.0602]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.5361 0.9242 0.2255 0.0148 0.2722]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  5
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.7124 0.2706 0.4859 0.7485 0.3584]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.5416 0.6232 0.3375 0.7195 0.0581]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.4326 0.7813 0.45   0.0665 0.2393]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 251.0, 136.0, 136.0]
# ***************
#
# bid:             [0.5953 0.6089 0.8665 0.607  0.7723]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.1929 0.9536 0.265  0.2681 0.0719]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 0.]
# offer:           [0.     0.2055 0.1378 0.2061 0.    ]
# payment:         [0.5493]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 344.0, 424.0, 625.0]
# ***************
# bid:             [0.9208 0.7528 0.2385 0.8697 0.4372]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.9344 0.9897 0.9424 0.3526 0.9468]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.0865 0.1281 0.6084 0.3439 0.0707]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 0. 1. 1. 0.]
# offer:           [0.     0.     0.1378 0.2061 0.    ]
# payment:         [0.3439]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 456.0, 426.0, 544.0]
# ***************
#
# bid:             [0.8658 0.2476 0.3213 0.1603 0.1951]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2488 0.2055 0.1378 0.     0.    ]
# payment:         [0.592]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 673.0]
# ***************
#
# bid:             [0.6531 0.4839 0.14   0.1903 0.8576]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.9599 0.5914 0.5139 0.6002 0.1278]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.8675 0.5631 0.9543 0.215  0.0166]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.1838 0.9388 0.5285 0.821  0.5256]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 1.]
# offer:           [0.     0.2055 0.1378 0.2061 0.2019]
# payment:         [0.7512]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 375.0, 344.0, 281.0, 0.0]
# ***************
#
# bid:             [0.4462 0.2199 0.1976 0.1314 0.728 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  3
# dp details: [327.0, 286.0, 354.0, 440.0, 673.0]
# ***************
#
# bid:             [0.8404 0.0515 0.5416 0.8901 0.3315]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.0242 0.0967 0.7525 0.2529 0.1966]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 0. 1. 1. 0.]
# offer:           [0.     0.     0.1378 0.2061 0.    ]
# payment:         [0.3439]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 456.0, 426.0, 544.0]
# ***************
#
# bid:             [0.1622 0.9921 0.2487 0.5619 0.0034]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 0.]
# offer:           [0.     0.2055 0.1378 0.2061 0.    ]
# payment:         [0.5493]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  5
# dp details: [327.0, 375.0, 344.0, 424.0, 201.0]
# ***************
#
# bid:             [0.7246 0.1927 0.9989 0.7382 0.2459]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.8952 0.5247 0.5985 0.0631 0.1211]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2488 0.2055 0.1378 0.     0.    ]
# payment:         [0.592]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [327.0, 286.0, 251.0, 136.0, 136.0]
# ***************
#
# bid:             [0.7938 0.6003 0.3746 0.125  0.1206]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2488 0.2055 0.1378 0.     0.    ]
# payment:         [0.592]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  5
# dp details: [327.0, 286.0, 251.0, 136.0, 136.0]
# ***************
#
# bid:             [0.874  0.7253 0.2094 0.2814 0.3542]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  5
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.8649 0.2318 0.2641 0.8905 0.8019]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  2
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.1775 0.2823 0.3548 0.8551 0.1177]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 1. 1. 1. 0.]
# offer:           [0.     0.2055 0.1378 0.2061 0.    ]
# payment:         [0.5493]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 456.0, 511.0, 489.0]
# ***************
#
# bid:             [0.652  0.469  0.0407 0.2009 0.1644]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 0. 0. 0.]
# offer:           [0.2488 0.2055 0.     0.     0.    ]
# payment:         [0.4543]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 286.0, 251.0, 387.0, 387.0]
# ***************
#
# bid:             [0.8918 0.1217 0.2602 0.0225 0.3559]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 0. 1.]
# offer:           [0.2488 0.     0.1378 0.     0.2019]
# payment:         [0.5884]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 673.0]
# ***************
#
# bid:             [0.7935 0.1666 0.1313 0.4695 0.0961]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 0. 1. 0.]
# offer:           [0.2488 0.     0.     0.2061 0.    ]
# payment:         [0.4549]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.3501 0.6062 0.5436 0.7751 0.668 ]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.0987 0.5088 0.1224 0.1553 0.2016]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0.     1.     0.     0.     0.9995]
# offer:           [0.     0.2055 0.     0.     0.2018]
# payment:         [0.4072]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 344.0, 424.0, 625.0]
# ***************
#
# bid:             [0.4854 0.4478 0.2291 0.5648 0.9241]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.483  0.275  0.92   0.6297 0.4043]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.4493 0.4506 0.5192 0.2201 0.6148]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.8245 0.0687 0.5559 0.9303 0.0501]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 0.]
# offer:           [0.2488 0.     0.1378 0.2061 0.    ]
# payment:         [0.5927]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.7741 0.2041 0.2638 0.5553 0.0562]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1.     0.0268 1.     1.     0.    ]
# offer:           [0.2488 0.0055 0.1378 0.2061 0.    ]
# payment:         [0.5982]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.963  0.5598 0.1371 0.5707 0.1767]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1.     1.     0.9749 1.     0.    ]
# offer:           [0.2488 0.2055 0.1343 0.2061 0.    ]
# payment:         [0.7947]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.3034 0.08   0.2883 0.9625 0.2452]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 375.0, 456.0, 511.0, 489.0]
# ***************
#
# bid:             [0.6356 0.0648 0.0277 0.2847 0.1974]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 0. 1. 0.]
# offer:           [0.2488 0.     0.     0.2061 0.    ]
# payment:         [0.4549]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  5  dp:  5
# dp details: [327.0, 286.0, 354.0, 440.0, 673.0]
# ***************
#
# bid:             [0.5496 0.543  0.4224 0.5204 0.8995]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.9111 0.019  0.8673 0.5485 0.5935]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 1. 1. 1.]
# offer:           [0.2488 0.     0.1378 0.2061 0.2019]
# payment:         [0.7945]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.6959 0.5818 0.7546 0.86   0.1249]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 0.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.    ]
# payment:         [0.7981]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.9697 0.3939 0.2457 0.9147 0.7463]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 251.0, 387.0, 0.0]
# ***************
#
# bid:             [0.8888 0.3304 0.6758 0.1531 0.0308]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 0.]
# offer:           [0.2488 0.2055 0.1378 0.     0.    ]
# payment:         [0.592]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  3  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.5411 0.2053 0.8021 0.5486 0.3719]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1.     0.9998 1.     1.     1.    ]
# offer:           [0.2488 0.2054 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0006]
#
# NN:  [0.0006]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.5813 0.2147 0.6735 0.8764 0.7256]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  1
# dp details: [327.0, 286.0, 354.0, 319.0, 0.0]
# ***************
#
# bid:             [0.7775 0.6798 0.6617 0.9353 0.3019]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 1. 1.]
# offer:           [0.2488 0.2055 0.1378 0.2061 0.2019]
# payment:         [1.]
# delay:           [0.0002]
#
# NN:  [0.0002]  cost-sharing:  0  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.6344 0.5316 0.7948 0.1583 0.9018]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 1. 1. 0. 1.]
# offer:           [0.2488 0.2055 0.1378 0.     0.2019]
# payment:         [0.7939]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  1  dp:  0
# dp details: [327.0, 286.0, 251.0, 136.0, 0.0]
# ***************
#
# bid:             [0.8698 0.111  0.0257 0.7004 0.7387]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [1. 0. 0. 1. 1.]
# offer:           [0.2488 0.     0.     0.2061 0.2019]
# payment:         [0.6568]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 286.0, 354.0, 440.0, 233.0]
# ***************
#
# bid:             [0.2359 0.0879 0.9485 0.7324 0.5386]
# Y1:              [0.2488 0.2055 0.1378 0.2061 0.2019]
# xor1:            [0. 0. 1. 1. 1.]
# offer:           [0.     0.     0.1378 0.2061 0.2019]
# payment:         [0.5457]
# delay:           [5.]
#
# NN:  [5.]  cost-sharing:  2  dp:  2
# dp details: [327.0, 375.0, 456.0, 426.0, 118.0]
# ***************

# %%
print(mi, ma)
print(sum(sum_list)/len(sum_list))
# Out:
# [0.0002] [5.]
# [3.3845]

# %%
data=np.array(sum_list)
data=data.reshape(-1)
#print(data.reshape(-1))

# %%
plt.hist(data,bins=300)
plt.show()

# %%
for i in range(len(sum_list)):
    sum_list[i]=np.round(sum_list[i]);
print(mi, ma)
print("NN:           ",sum(sum_list)/len(sum_list))
# Out:
# [0.0002] [5.]
# NN:            [3.3845]

# %%
print("cost-sharing: ",total_delay_cost/test_number_cost);
# Out:
# cost-sharing:  1.4131

# %%
print("dp:           ",dp[nn][0][divide_number]);
# Out:
# dp:            1.6223377207976672

# %%
print(sum(list_payment)/len(list_payment))
# Out:
# [0.7945]

# %% [markdown]
# ####

# %% [markdown]
# #####
