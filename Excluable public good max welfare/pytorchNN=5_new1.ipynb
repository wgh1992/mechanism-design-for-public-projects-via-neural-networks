# %%
global n
n = 5
epochs = 1
supervisionEpochs = 1
lr1 = 0.01
lr2 = 0.00001
log_interval = 5
trainSize = 40000#100000
percentage_train_test= 0.5
penaltyLambda = 10
dpPrecision=50
pdfPrecision=100
init_weights="xavier_normal"#"kaiming_uniform""kaiming_normal""xavier_uniform"

# %%
import itertools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import torch.distributions as D
from torch.utils.data import DataLoader, TensorDataset
from pylab import *
from scipy.stats import beta
import math
from localfiles import mydistribution
global samplesJoint,tp_dataloader,tp_dataloader_testing,dp,decision,dp_H,decision_H
global decision_offer,decision_welfare,record_ans

# %%
stage=["twopeak"]
# "twopeak","normal","uniform","independent1","independent2","cauchy","beta","U-exponential","arcsine"
order1name=["dp","random initializing","costsharing","heuristic"]
#order1name=["random initializing1","random initializing2","random initializing3"]
# "costsharing","dp","heuristic","random initializing"

# %%
print(mydistribution)
mydistribution.inital(n)
# Out:
# <module 'localfiles.mydistribution' from 'D:\\coding\\jupyter workplace\\Mechanism Design\\Public Good\\Excluable public good max welfare\\localfiles\\mydistribution.py'>
# 0.3540388371733616

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()
# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU not available, CPU used

# %%
global record_ans
record_ans=0
def recordAndReport(name, source, loss):
    source.append(loss)
    realLength = len(source)
    #print(f"{name} ({realLength}): {loss}")
    print(name,realLength,":" ,loss)

# %%
def bitsToPayments(bits):
    if torch.sum(bits).item() == 0:
        return torch.ones(n)
    bits     = bits.type(torch.float32)
    negBits  = torch.ones(n) - bits
    payments = model(bits)
    payments = payments - 1000 * negBits
    payments = torch.softmax(payments, 0)
    payments = payments + negBits
    return payments

def tpToBits(tp, bits=torch.ones(n).type(torch.uint8)):
    payments = bitsToPayments(bits)
    newBits = (tp >= payments).type(torch.uint8)
    if torch.equal(newBits, bits):
        return bits
    else:
        return tpToBits(tp, newBits)#bits-bits#tpToBits(tp, newBits)

def tpToPayments(tp):
    return bitsToPayments(tpToBits(tp))


def tpToTotalWelfare(tp):
    return torch.max(torch.tensor(0.0),torch.dot(tp,tpToBits(tp).type(torch.float32))-1.0)

# %%
def dpSupervisionRule(tp):
    global decision_offer,decision_welfare
    global record_ans
    global  dp,decision
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    money = dpPrecision
    record_=0
    for i in range(n):
        offerIndex = decision_offer[n - i, money,record_]
        offer = float(offerIndex) / dpPrecision
        if tp[i] > offer:
            money -= offerIndex
            bits[i] = 1
            record_ = decision_welfare[n - i, money, record_]
            payments[i] = offer
        else:
            bits[i] = 0
            payments[i] = 1
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
#     print()
#     print(tp)
#     print(bits)
#     print(payments)
#     print()
    return (bits, payments)


def heuristicSupervisionRule(tp):
    global  dp_H,decision_H
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    tempold=-1;
    for turns in range(n,0,-1):
        money = dpPrecision
        j=0
        tempo=sum(bits)
        #print("bits",tempo)
        for i in range(n):
            if(j>=n):
                break;
            
            offerIndex = decision_H[tempo ,tempo - i, money]
            offer = float(offerIndex) / dpPrecision
            while(j<n):
                if(bits[j]!=0):
                    break;
                j+=1;
            if(j>=n):
                break;
            if tp[j] >= offer:
                #print(money,j,tp[j],offer)
                money -= offerIndex
                bits[j] = 1
                payments[j] = offer
            else:
                bits[j] = 0;
                payments[j] = 1.0;
            j+=1;
        #print("money",money)
        if(money==0 and tempold==tempo):
            break;
        tempold=tempo;
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]

    bits = torch.tensor(bits, dtype=torch.float32)
    payments = torch.tensor(payments, dtype=torch.float32)
    # print()
    # print(tp)
    # print(bits)
    # print(payments)
    # print()
    return (bits, payments)



def costSharingSupervisionRule(tp):
    tp = list(tp.numpy())
    for k in range(n, -1, -1):
        if k == 0:
            break
        bits = [1 if tp[ii] >= 1.0 / k else 0 for ii in range(n)]
        if sum(bits) == k:
            break
    if k == 0:
        bits = [0 for ii in range(n)]
        payments = [1 for ii in range(n)]
    else:
        payments = [1.0 / k if bits[ii] == 1 else 1 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
    return (bits, payments)

    
def costSharingWelfare(tp):
    #print(tp,costSharingSupervisionRule(tp)[0])
    return max(0.0,float(torch.dot(tp,torch.tensor(costSharingSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def dpWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(dpSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def heuristicWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(heuristicSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def tpToTotalDelay(tp):
    return n - torch.sum(tpToBits(tp).type(torch.float32))

# %%
def supervisionTrain(epoch, supervisionRule):
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss = penalty * penaltyLambda /100000
        
        for tp in tp_batch:
            bits, payments = supervisionRule(tp)
            loss += F.mse_loss(bitsToPayments(bits), payments)

        loss = loss / len(tp_batch)
        loss.backward()
        optimizer.step()
        if batch_idx % (log_interval*5) == 0:
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                )
            )

losslist=[];
losslistname=[];
losslisttemp=[];
def test_batch():
    global losslisttemp; 
    model.eval()
    with torch.no_grad():
        lenLoss= 0
        nnLoss = 0
        for (tp_batch,) in tp_dataloader_testing:
            for tp in tp_batch:
                nnLoss += tpToTotalWelfare(tp)
            lenLoss+=len(tp_batch)
        nnLoss/=lenLoss
    return nnLoss


def train(epoch):
    global record_ans
    global losslisttemp; 
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        loss=0;
        for tp in tp_batch:
            for i in range(n):
                tp1 = tp.clone()
                tp1[i] = 1
                tp0 = tp.clone()
                tp0[i] = 0
                offer = tpToPayments(tp1)[i]
                Welfare1 = tpToTotalWelfare(tp1)
                Welfare0 = tpToTotalWelfare(tp0)
                offerIndex=int(offer*dpPrecision)
                if(order!="independent1" and order!="independent2"):
                    losspart2= (utilitya[offerIndex]*offer+utilityb[offerIndex])*1
                    loss -= (1 - mydistribution.cdf(offer,order)) * (Welfare1+losspart2-losspart2.item()) + mydistribution.cdf(offer,order) * Welfare0
                else:
                    loss -= (1 - mydistribution.cdf(offer,order,i)) * Welfare1 + mydistribution.cdf(offer,order,i) * Welfare0
                    
                Delay1 = tpToTotalDelay(tp1)
                Delay0 = tpToTotalDelay(tp0)
                if(order!="independent1" and order!="independent2"):
                    loss += (1 - mydistribution.cdf(offer,order)) * Delay1 + mydistribution.cdf(offer,order) * Delay0
                else:
                    loss += (1 - mydistribution.cdf(offer,order,i)) * Delay1 + mydistribution.cdf(offer,order,i) * Delay0
        loss = loss / len(tp_batch) / n
        
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss += penalty * penaltyLambda
        
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            losstemp=test_batch();
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                ),"testing loss:",losstemp
            )
            losslisttemp.append(losstemp);
            
    print("penalty:",penalty.item())
    
allBits = [torch.tensor(bits, dtype=torch.int16) for bits in itertools.product([0, 1], repeat=n)]

def test():
    global record_ans
    global losslisttemp; 
    model.eval()

    with torch.no_grad():
        costSharingLoss = 0
        dpLoss = 0
        nnLoss = 0
        heuristicLoss=0
        lenLoss= 0
        for (tp_batch,) in tp_dataloader_testing:

            for tp in tp_batch:
                costSharingLoss += costSharingWelfare(tp)
                dpLoss += dpWelfare(tp)
                nnLoss += tpToTotalWelfare(tp)
                heuristicLoss+= heuristicWelfare(tp)
            lenLoss+=len(tp_batch)
        costSharingLoss /= lenLoss
        dpLoss /= lenLoss
        nnLoss /= lenLoss
        heuristicLoss /= lenLoss
        #print(lenLoss)
        losslisttemp.append(nnLoss);
        recordAndReport("NN", runningLossNN, nnLoss)
        recordAndReport("CS", runningLossCS, costSharingLoss)
        recordAndReport("DP", runningLossDP, dpLoss)
        recordAndReport("heuristic", runningLossHeuristic, heuristicLoss)
        print("DP:",dp[n, dpPrecision,0])
        #for i in range(n, 0, -1):
        #    print("Heuristic:",i,5*(1-dp_H[i, i, dpPrecision]))
        for i in range(n, 0, -1):
            print(
                    tpToPayments(
                            torch.tensor([0 if ii >= i else 1 for ii in range(n)], dtype=torch.float32)
                    )
                )

# %%
def run_dp():
    global decision_offer,decision_welfare,decision_H
    global dp,dp_H,record_ans,utilitya,utilityb
    pdfnumber=[0 for i in range(pdfPrecision+1)];
    cdfnumber=[0 for i in range(pdfPrecision+1)];
    utilitynumber=[0 for i in range(pdfPrecision+1)];
    Possible_utility=[0 for i in range(pdfPrecision+1)];
    utilitya=[0 for i in range(dpPrecision+1)];
    utilityb=[0 for i in range(dpPrecision+1)];
    for i in range(int(trainSize * percentage_train_test)):
        for j in range(n):
            pdfnumber[int(samplesJoint[i,j]*pdfPrecision)]+=1.0/int(trainSize * percentage_train_test*n)
    cdfnumber[0]=pdfnumber[0];
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]
    #print(cdfnumber)  
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]   
    for i in range(0,pdfPrecision+1):
        utilitynumber[i]=0
        for j in range(i,pdfPrecision+1):
            utilitynumber[i]+=pdfnumber[j]*float(j-i)/pdfPrecision
        if(sum(pdfnumber[i:])!=0):
            utilitynumber[i]/=sum(pdfnumber[i:])
    for i in range(0,dpPrecision):
        ii=int(float(i)/dpPrecision*pdfPrecision)
        jj=int(float(i+1)/dpPrecision*pdfPrecision)
        utilitya[i]=(utilitynumber[jj]-utilitynumber[ii])/dpPrecision
        utilityb[i]=utilitynumber[ii]-utilitya[i]*float(i)/dpPrecision
    plt.plot(pdfnumber)
    plt.show()
    print(sum(pdfnumber))

    plt.plot(utilitynumber)
    plt.show()
    
    
    # howManyPpl left, money left, yes already
    dp        = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1])
    decision_offer = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    decision_welfare = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    for yes in range(dpPrecision*n + 1):
        for money in range(dpPrecision + 1):
                offer = float(money) / dpPrecision                                                                     
                dp[1, money, yes] =(1.0 - mydistribution.cdf(offer,order).item()) * (yes/dpPrecision + utilitynumber[round(offer*pdfPrecision)])
                decision_offer[1, money, yes] = money
                decision_welfare[1, money, yes] = int(yes + utilitynumber[round(offer*pdfPrecision)]*dpPrecision)
    for ppl in range(2,  n + 1):
        for yes in range(dpPrecision*n + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -100000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        
                        res = (1 - mydistribution.cdf(offer,order)) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order) * (dp[ppl - 1, money, yes])
                    else:
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        res = (1 - mydistribution.cdf(offer,order,n-ppl).item()) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order,n-ppl).item() * (dp[ppl - 1, money, yes])
                    if maxSoFar < res:
                        maxSoFar = res
                        decision_offer[ppl, money, yes] = offerIndex
                        decision_welfare[ppl, money, yes] = yes_old
                dp[ppl, money, yes] = maxSoFar
    
    print("dp",dp[n, dpPrecision, 0])
    
    def verify_dp(temp,debug):
        if(debug==1):
            print(temp)
        ans =0;
        o_list=[];
        remain_list=[];
        remain=dpPrecision
        record_= 0
        for ppl in range(n,0,-1):
            o=decision_offer[ppl, remain, record_]
            
            #print("record",o,record_)
            if(debug==1):
                print(o,remain,record_)
            o_list.append(o)
            remain_list.append(remain);
            if(o<temp[n-ppl]):
                remain-=int(o);
                record_=decision_welfare[ppl, remain, record_]
                ans=1#+=float(temp[n-ppl]-o)/dpPrecision
                #print("record",record_)
            elif (remain>0):
                ans=0;
        if(remain<=1):
            return ans,o_list;
        else:
            return 0,o_list;
    ans_list=[];
    for i in range(5):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        tempres=verify_dp(temp,1)
        ans_list.append(tempres[0]);
        print(tempres)
        #print("\n",temp)
        #print(plan_dp(temp,1))

    for i in range(10000):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        ans_list.append(verify_dp(temp,0)[0]);
        #print("\n",temp)
        #print(plan_dp(temp))
    print("verify dp vaule:",sum(ans_list)/len(ans_list))
    
    # howManyPpl left, money left, yes already
    dp_H = np.zeros([n + 1 , n + 1, dpPrecision + 1])
    decision_H = np.zeros([n + 1 , n + 1, dpPrecision + 1], dtype=np.uint8)
    # ppl = 0 left
    for i in range(1,n+1):
        for money in range(dpPrecision + 1):
            if money == 0:
                dp_H[i, 0, 0] = 1
            else:
                offer = money / dpPrecision
                dp_H[i, 0, money] = 0#mydistribution.cdf(offer)# + 1.0
    for i in range(1,n+1):
        for ppl in range(1, i + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -1000000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        res = (1-mydistribution.cdf(offer,order)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    else:
                        res = (1-mydistribution.cdf(offer,order,ppl-1)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    if maxSoFar < res.item():
                        maxSoFar = res.item()
                        decision_H[i, ppl, money] = offerIndex
                dp_H[i, ppl, money] = maxSoFar

# %%
def init_weights_xavier_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
def init_weights_xavier_normal(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_normal_(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.1)

# %%
for order in stage:
    samplesJoint=mydistribution.producedata(order,trainSize)
    tp_tensor = torch.tensor(samplesJoint, dtype=torch.float32)
    tp_dataset = TensorDataset(tp_tensor[: int(trainSize * percentage_train_test)])
    tp_dataset_testing = TensorDataset(tp_tensor[int(trainSize * (1.0-percentage_train_test)) :])
    tp_dataloader = DataLoader(tp_dataset, batch_size=128, shuffle=True)
    tp_dataloader_testing = DataLoader(tp_dataset_testing, batch_size=256, shuffle=False)
    run_dp()
    #running
    for order1 in order1name:
        print("Supervised Aim:",order,order1)
        
        # Instantiate the model with hyperparameters
        model = nn.Sequential(
            nn.Linear(n, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, n),
        )
        if(init_weights=="xavier_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="xavier_normal"):
            model.apply(init_weights_xavier_normal)
        if(init_weights=="kaiming_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="kaiming_normal"):
            model.apply(init_weights_xavier_normal)
        # optimizer = optim.SGD(model.parameters(), lr=lr)
        optimizer = optim.Adam(model.parameters(), lr=lr1)
        print(model)
        
        runningLossNN = []
        runningLossCS = []
        runningLossDP = []
        runningLossHeuristic = []
        #model=torch.load("save/pytorchNN=5dp1");
        #model.eval()
        ##order1name=["costsharing","dp","heuristic","random initializing"]
        for epoch in range(1, supervisionEpochs + 1):
#             print("distributionRatio",distributionRatio)
            if(order1=="costsharing"):
                supervisionTrain(epoch, costSharingSupervisionRule)
            elif(order1=="dp"):
                supervisionTrain(epoch, dpSupervisionRule)
            elif(order1=="heuristic"):
                supervisionTrain(epoch, heuristicSupervisionRule)
            elif(order1=="random initializing"):
                print("do nothing");

        test()
        optimizer = optim.Adam(model.parameters(), lr=lr2)
        for epoch in range(1, epochs + 1):
            train(epoch)
            test()
        losslistname.append(order+" "+order1);
        losslist.append(losslisttemp);
        losslisttemp=[];
        savepath="save/pytorchNN=5all-beta"+order+str(order1)
        torch.save(model, savepath);
        print("end")
        print()
# Out:
# loc 0.2 scale 0.1
# loc 0.6 scale 0.1
# 0.9999999999999734
# dp 0.7439563870429993
# [24.81640756 28.26682492 33.19202275 35.96288007  8.53402205]
# 23 50 0
# 9 27 15
# 9 18 31
# 8 9 48
# 1 1 67
# (1, [23, 9, 9, 8, 1])
# [ 9.77804529  7.79865844  8.01713136 34.12953855 41.353944  ]
# 23 50 0
# 23 50 0
# 23 50 0
# 26 50 0
# 24 24 11
# (1, [23, 23, 23, 26, 24])
# [10.71506698  7.14972306 38.96046129  0.67256049 26.4309218 ]
# 23 50 0
# 23 50 0
# 23 50 0
# 23 27 14
# 27 27 14
# (0, [23, 23, 23, 23, 27])
# [27.07383611 38.19778594 17.76883541 31.20591425 33.92621427]
# 23 50 0
# 9 27 15
# 9 18 31
# 8 9 48
# 1 1 67
# (1, [23, 9, 9, 8, 1])
# [13.19853923 28.58302351 34.01811203 29.1187417   6.89174962]
# 23 50 0
# 23 50 0
# 16 27 15
# 9 11 31
# 2 2 49
# (1, [23, 23, 16, 9, 2])
# verify dp vaule: 0.727336331834083
# Supervised Aim: twopeak dp
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.015507
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000443
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000089
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000010
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000005
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000002
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000002
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:105: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:108: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NN 1 : tensor(0.7517)
# CS 1 : 0.78982356492877
# DP 1 : 0.7396951515138149
# heuristic 1 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.4599, 0.1794, 0.1790, 0.1591, 0.0225])
# tensor([0.4928, 0.1797, 0.1782, 0.1493, 1.0000])
# tensor([0.5856, 0.2045, 0.2099, 1.0000, 1.0000])
# tensor([0.7445, 0.2555, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 2.041654 testing loss: tensor(0.7517)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 2.169709 testing loss: tensor(0.7518)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 2.038312 testing loss: tensor(0.7520)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.919589 testing loss: tensor(0.7519)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 2.098879 testing loss: tensor(0.7520)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 2.059227 testing loss: tensor(0.7520)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.483129 testing loss: tensor(0.7519)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.640805 testing loss: tensor(0.7518)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.621535 testing loss: tensor(0.7520)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.690961 testing loss: tensor(0.7519)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.657381 testing loss: tensor(0.7520)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.506353 testing loss: tensor(0.7519)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 1.864667 testing loss: tensor(0.7520)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.645850 testing loss: tensor(0.7520)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 1.707050 testing loss: tensor(0.7520)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.701475 testing loss: tensor(0.7519)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.681711 testing loss: tensor(0.7520)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.433616 testing loss: tensor(0.7520)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.582280 testing loss: tensor(0.7519)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.737291 testing loss: tensor(0.7518)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.421709 testing loss: tensor(0.7519)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.381195 testing loss: tensor(0.7518)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.747009 testing loss: tensor(0.7519)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 1.564887 testing loss: tensor(0.7517)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 1.626555 testing loss: tensor(0.7515)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 1.639422 testing loss: tensor(0.7515)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.743218 testing loss: tensor(0.7514)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 1.533958 testing loss: tensor(0.7513)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.554666 testing loss: tensor(0.7514)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 1.403877 testing loss: tensor(0.7513)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.311859 testing loss: tensor(0.7513)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.392009 testing loss: tensor(0.7513)
# penalty: 0.035667501389980316
# NN 2 : tensor(0.7512)
# CS 2 : 0.78982356492877
# DP 2 : 0.7396951515138149
# heuristic 2 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.4621, 0.1801, 0.1752, 0.1608, 0.0218])
# tensor([0.4901, 0.1801, 0.1750, 0.1548, 1.0000])
# tensor([0.5856, 0.2068, 0.2075, 1.0000, 1.0000])
# tensor([0.7435, 0.2565, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak random initializing
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# do nothing
# NN 1 : tensor(0.7648)
# CS 1 : 0.78982356492877
# DP 1 : 0.7396951515138149
# heuristic 1 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.1353, 0.1167, 0.2905, 0.2810, 0.1766])
# tensor([0.1473, 0.1473, 0.3518, 0.3536, 1.0000])
# tensor([0.2416, 0.2525, 0.5059, 1.0000, 1.0000])
# tensor([0.5772, 0.4228, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.140023 testing loss: tensor(0.7649)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 0.892993 testing loss: tensor(0.7652)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.487366 testing loss: tensor(0.7657)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.026814 testing loss: tensor(0.7661)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 1.369279 testing loss: tensor(0.7665)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 1.227563 testing loss: tensor(0.7672)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.256053 testing loss: tensor(0.7679)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.380581 testing loss: tensor(0.7683)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 0.930655 testing loss: tensor(0.7689)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 0.936208 testing loss: tensor(0.7693)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.045258 testing loss: tensor(0.7699)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 0.894535 testing loss: tensor(0.7702)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 1.067127 testing loss: tensor(0.7706)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 0.923012 testing loss: tensor(0.7711)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 0.855867 testing loss: tensor(0.7712)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.995331 testing loss: tensor(0.7715)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.141935 testing loss: tensor(0.7718)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 0.919619 testing loss: tensor(0.7725)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.102620 testing loss: tensor(0.7725)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.144297 testing loss: tensor(0.7729)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.941998 testing loss: tensor(0.7731)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 0.907258 testing loss: tensor(0.7738)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.007797 testing loss: tensor(0.7742)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 0.904602 testing loss: tensor(0.7738)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 1.250636 testing loss: tensor(0.7738)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.947985 testing loss: tensor(0.7741)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.069683 testing loss: tensor(0.7745)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 0.842287 testing loss: tensor(0.7747)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.125808 testing loss: tensor(0.7749)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 0.793738 testing loss: tensor(0.7750)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.020155 testing loss: tensor(0.7752)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.089313 testing loss: tensor(0.7754)
# penalty: 0.0
# NN 2 : tensor(0.7755)
# CS 2 : 0.78982356492877
# DP 2 : 0.7396951515138149
# heuristic 2 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.1414, 0.1456, 0.3114, 0.2486, 0.1531])
# tensor([0.1520, 0.1786, 0.3636, 0.3058, 1.0000])
# tensor([0.2255, 0.2785, 0.4961, 1.0000, 1.0000])
# tensor([0.5276, 0.4724, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak costsharing
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.001794
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000009
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000001
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000000
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000000
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000000
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000000
# NN 1 : tensor(0.7897)
# CS 1 : 0.78982356492877
# DP 1 : 0.7396951515138149
# heuristic 1 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.1999, 0.2000, 0.2001, 0.1999, 0.2001])
# tensor([0.2507, 0.2493, 0.2497, 0.2504, 1.0000])
# tensor([0.3329, 0.3338, 0.3334, 1.0000, 1.0000])
# tensor([0.5003, 0.4997, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.719731 testing loss: tensor(0.7897)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.072534 testing loss: tensor(0.7898)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 0.706017 testing loss: tensor(0.7897)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.083552 testing loss: tensor(0.7898)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 0.919800 testing loss: tensor(0.7898)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.812824 testing loss: tensor(0.7898)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 0.795039 testing loss: tensor(0.7899)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.129780 testing loss: tensor(0.7899)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.038314 testing loss: tensor(0.7899)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 0.607169 testing loss: tensor(0.7899)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.046947 testing loss: tensor(0.7900)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.244398 testing loss: tensor(0.7899)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 0.879725 testing loss: tensor(0.7899)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.162033 testing loss: tensor(0.7899)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 0.951465 testing loss: tensor(0.7898)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.192640 testing loss: tensor(0.7899)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.161223 testing loss: tensor(0.7898)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.173953 testing loss: tensor(0.7897)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.019907 testing loss: tensor(0.7897)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.027511 testing loss: tensor(0.7897)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.055090 testing loss: tensor(0.7897)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 0.768645 testing loss: tensor(0.7897)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 0.942144 testing loss: tensor(0.7897)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 0.656310 testing loss: tensor(0.7897)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 0.878755 testing loss: tensor(0.7897)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.699790 testing loss: tensor(0.7897)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.105235 testing loss: tensor(0.7897)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 0.856900 testing loss: tensor(0.7897)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 0.815251 testing loss: tensor(0.7897)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 0.771722 testing loss: tensor(0.7897)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.908481 testing loss: tensor(0.7897)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.017744 testing loss: tensor(0.7897)
# penalty: 0.0
# NN 2 : tensor(0.7897)
# CS 2 : 0.78982356492877
# DP 2 : 0.7396951515138149
# heuristic 2 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.2007, 0.2001, 0.1995, 0.2001, 0.1997])
# tensor([0.2515, 0.2491, 0.2489, 0.2505, 1.0000])
# tensor([0.3338, 0.3338, 0.3324, 1.0000, 1.0000])
# tensor([0.5009, 0.4991, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak heuristic
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.007481
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000740
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000130
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000031
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000026
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000011
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000012
# NN 1 : tensor(0.7719)
# CS 1 : 0.78982356492877
# DP 1 : 0.7396951515138149
# heuristic 1 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.1210, 0.1388, 0.1425, 0.1398, 0.4579])
# tensor([0.1770, 0.1589, 0.1821, 0.4820, 1.0000])
# tensor([0.1206, 0.4394, 0.4400, 1.0000, 1.0000])
# tensor([0.4979, 0.5021, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 15.601789 testing loss: tensor(0.7720)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 15.833880 testing loss: tensor(0.7722)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 15.760339 testing loss: tensor(0.7725)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 15.528049 testing loss: tensor(0.7726)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 15.331795 testing loss: tensor(0.7727)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 15.121564 testing loss: tensor(0.7731)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 14.974393 testing loss: tensor(0.7731)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 14.978545 testing loss: tensor(0.7733)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 14.939474 testing loss: tensor(0.7735)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 14.723678 testing loss: tensor(0.7737)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 14.685062 testing loss: tensor(0.7739)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 14.103207 testing loss: tensor(0.7740)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 14.024532 testing loss: tensor(0.7744)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 14.119851 testing loss: tensor(0.7745)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 13.685591 testing loss: tensor(0.7746)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 13.520554 testing loss: tensor(0.7749)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 13.619399 testing loss: tensor(0.7749)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 13.557370 testing loss: tensor(0.7751)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 13.510069 testing loss: tensor(0.7753)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 13.356162 testing loss: tensor(0.7754)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 13.028983 testing loss: tensor(0.7755)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 12.736704 testing loss: tensor(0.7757)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 12.611598 testing loss: tensor(0.7759)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 12.623139 testing loss: tensor(0.7761)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 12.498468 testing loss: tensor(0.7762)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 12.562524 testing loss: tensor(0.7762)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 12.147155 testing loss: tensor(0.7763)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 12.303738 testing loss: tensor(0.7764)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 11.902241 testing loss: tensor(0.7764)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 12.071716 testing loss: tensor(0.7766)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 11.798702 testing loss: tensor(0.7766)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 11.652181 testing loss: tensor(0.7766)
# penalty: 1.065181016921997
# NN 2 : tensor(0.7766)
# CS 2 : 0.78982356492877
# DP 2 : 0.7396951515138149
# heuristic 2 : 0.7340714952409267
# DP: 0.7439563870429993
# tensor([0.1251, 0.1429, 0.1394, 0.1410, 0.4516])
# tensor([0.1827, 0.1734, 0.1851, 0.4588, 1.0000])
# tensor([0.1386, 0.4431, 0.4183, 1.0000, 1.0000])
# tensor([0.5049, 0.4951, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end

# %%
colorlist=["#D2691E",'#4169E1',"#9ACD32","#B22222","#FF00FF","#708090"]
for i in range(len(losslist)):
    plt.plot(losslist[i], '.-', color=colorlist[i], alpha=0.8, label=losslistname[i])

# 显示标签，如果不加这句，即使加了label='一些数字'的参数，最终还是不会显示标签
plt.legend(loc="best")
plt.xlabel('Trianing Times')
plt.ylabel('Welfare')

plt.show()
