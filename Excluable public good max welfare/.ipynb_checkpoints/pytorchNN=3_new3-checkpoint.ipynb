# %%
global n
n = 3
epochs = 1
supervisionEpochs = 1
lr1 = 0.01
lr2 = 0.0001
log_interval = 5
trainSize = 40000#100000
percentage_train_test= 0.5
penaltyLambda = 10
dpPrecision=50
pdfPrecision=100
init_weights="xavier_normal"#"kaiming_uniform""kaiming_normal""xavier_uniform"

# %%
import itertools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import torch.distributions as D
from torch.utils.data import DataLoader, TensorDataset
from pylab import *
from scipy.stats import beta
import math
from localfiles import mydistribution
global samplesJoint,tp_dataloader,tp_dataloader_testing,dp,decision,dp_H,decision_H
global decision_offer,decision_welfare,record_ans

# %%
stage=["U-exponential"]
# "twopeak","normal","uniform","independent1","independent2","cauchy","beta","U-exponential","arcsine"
order1name=["dp","random initializing","costsharing","heuristic"]
#order1name=["random initializing1","random initializing2","random initializing3"]
# "costsharing","dp","heuristic","random initializing"

# %%
print(mydistribution)
mydistribution.inital(n)
# Out:
# <module 'localfiles.mydistribution' from 'D:\\coding\\jupyter workplace\\Mechanism Design\\Public Good\\Excluable public good max welfare\\localfiles\\mydistribution.py'>
# 0.3540388371733616

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()
# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU not available, CPU used

# %%
global record_ans
record_ans=0
def recordAndReport(name, source, loss):
    source.append(loss)
    realLength = len(source)
    #print(f"{name} ({realLength}): {loss}")
    print(name,realLength,":" ,loss)

# %%
def bitsToPayments(bits):
    if torch.sum(bits).item() == 0:
        return torch.ones(n)
    bits     = bits.type(torch.float32)
    negBits  = torch.ones(n) - bits
    payments = model(bits)
    payments = payments - 1000 * negBits
    payments = torch.softmax(payments, 0)
    payments = payments + negBits
    return payments

def tpToBits(tp, bits=torch.ones(n).type(torch.uint8)):
    payments = bitsToPayments(bits)
    newBits = (tp >= payments).type(torch.uint8)
    if torch.equal(newBits, bits):
        return bits
    else:
        return tpToBits(tp, newBits)#bits-bits#tpToBits(tp, newBits)

def tpToPayments(tp):
    return bitsToPayments(tpToBits(tp))


def tpToTotalWelfare(tp):
    return torch.max(torch.tensor(0.0),torch.dot(tp,tpToBits(tp).type(torch.float32))-1.0)

# %%
def dpSupervisionRule(tp):
    global decision_offer,decision_welfare
    global record_ans
    global  dp,decision
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    money = dpPrecision
    record_=0
    for i in range(n):
        offerIndex = decision_offer[n - i, money,record_]
        offer = float(offerIndex) / dpPrecision
        if tp[i] > offer:
            money -= offerIndex
            bits[i] = 1
            record_ = decision_welfare[n - i, money, record_]
            payments[i] = offer
        else:
            bits[i] = 0
            payments[i] = 1
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
#     print()
#     print(tp)
#     print(bits)
#     print(payments)
#     print()
    return (bits, payments)


def heuristicSupervisionRule(tp):
    global  dp_H,decision_H
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    tempold=-1;
    for turns in range(n,0,-1):
        money = dpPrecision
        j=0
        tempo=sum(bits)
        #print("bits",tempo)
        for i in range(n):
            if(j>=n):
                break;
            
            offerIndex = decision_H[tempo ,tempo - i, money]
            offer = float(offerIndex) / dpPrecision
            while(j<n):
                if(bits[j]!=0):
                    break;
                j+=1;
            if(j>=n):
                break;
            if tp[j] >= offer:
                #print(money,j,tp[j],offer)
                money -= offerIndex
                bits[j] = 1
                payments[j] = offer
            else:
                bits[j] = 0;
                payments[j] = 1.0;
            j+=1;
        #print("money",money)
        if(money==0 and tempold==tempo):
            break;
        tempold=tempo;
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]

    bits = torch.tensor(bits, dtype=torch.float32)
    payments = torch.tensor(payments, dtype=torch.float32)
    # print()
    # print(tp)
    # print(bits)
    # print(payments)
    # print()
    return (bits, payments)



def costSharingSupervisionRule(tp):
    tp = list(tp.numpy())
    for k in range(n, -1, -1):
        if k == 0:
            break
        bits = [1 if tp[ii] >= 1.0 / k else 0 for ii in range(n)]
        if sum(bits) == k:
            break
    if k == 0:
        bits = [0 for ii in range(n)]
        payments = [1 for ii in range(n)]
    else:
        payments = [1.0 / k if bits[ii] == 1 else 1 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
    return (bits, payments)

    
def costSharingWelfare(tp):
    #print(tp,costSharingSupervisionRule(tp)[0])
    return max(0.0,float(torch.dot(tp,torch.tensor(costSharingSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def dpWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(dpSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def heuristicWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(heuristicSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def tpToTotalDelay(tp):
    return n - torch.sum(tpToBits(tp).type(torch.float32))

# %%
def supervisionTrain(epoch, supervisionRule):
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss = penalty * penaltyLambda /100000
        
        for tp in tp_batch:
            bits, payments = supervisionRule(tp)
            loss += F.mse_loss(bitsToPayments(bits), payments)

        loss = loss / len(tp_batch)
        loss.backward()
        optimizer.step()
        if batch_idx % (log_interval*5) == 0:
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                )
            )

losslist=[];
losslistname=[];
losslisttemp=[];
def test_batch():
    global losslisttemp; 
    model.eval()
    with torch.no_grad():
        lenLoss= 0
        nnLoss = 0
        for (tp_batch,) in tp_dataloader_testing:
            for tp in tp_batch:
                nnLoss += tpToTotalWelfare(tp)
            lenLoss+=len(tp_batch)
        nnLoss/=lenLoss
    return nnLoss


def train(epoch):
    global record_ans
    global losslisttemp; 
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        loss=0;
        for tp in tp_batch:
            for i in range(n):
                tp1 = tp.clone()
                tp1[i] = 1
                tp0 = tp.clone()
                tp0[i] = 0
                offer = tpToPayments(tp1)[i]
                Welfare1 = tpToTotalWelfare(tp1)
                Welfare0 = tpToTotalWelfare(tp0)
                offerIndex=int(offer*dpPrecision)
                if(order!="independent1" and order!="independent2"):
                    losspart2= (utilitya[offerIndex]*offer+utilityb[offerIndex])*1
                    loss -= (1 - mydistribution.cdf(offer,order)) * (Welfare1+losspart2-losspart2.item()) + mydistribution.cdf(offer,order) * Welfare0
                else:
                    loss -= (1 - mydistribution.cdf(offer,order,i)) * Welfare1 + mydistribution.cdf(offer,order,i) * Welfare0
                    
                Delay1 = tpToTotalDelay(tp1)
                Delay0 = tpToTotalDelay(tp0)
                if(order!="independent1" and order!="independent2"):
                    loss += (1 - mydistribution.cdf(offer,order)) * Delay1 + mydistribution.cdf(offer,order) * Delay0
                else:
                    loss += (1 - mydistribution.cdf(offer,order,i)) * Delay1 + mydistribution.cdf(offer,order,i) * Delay0
        loss = loss / len(tp_batch) / n
        
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss += penalty * penaltyLambda
        
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            losstemp=test_batch();
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                ),"testing loss:",losstemp
            )
            losslisttemp.append(losstemp);
            
    print("penalty:",penalty.item())
    
allBits = [torch.tensor(bits, dtype=torch.int16) for bits in itertools.product([0, 1], repeat=n)]

def test():
    global record_ans
    global losslisttemp; 
    model.eval()

    with torch.no_grad():
        costSharingLoss = 0
        dpLoss = 0
        nnLoss = 0
        heuristicLoss=0
        lenLoss= 0
        for (tp_batch,) in tp_dataloader_testing:

            for tp in tp_batch:
                costSharingLoss += costSharingWelfare(tp)
                dpLoss += dpWelfare(tp)
                nnLoss += tpToTotalWelfare(tp)
                heuristicLoss+= heuristicWelfare(tp)
            lenLoss+=len(tp_batch)
        costSharingLoss /= lenLoss
        dpLoss /= lenLoss
        nnLoss /= lenLoss
        heuristicLoss /= lenLoss
        #print(lenLoss)
        losslisttemp.append(nnLoss);
        recordAndReport("NN", runningLossNN, nnLoss)
        recordAndReport("CS", runningLossCS, costSharingLoss)
        recordAndReport("DP", runningLossDP, dpLoss)
        recordAndReport("heuristic", runningLossHeuristic, heuristicLoss)
        print("DP:",dp[n, dpPrecision,0])
        #for i in range(n, 0, -1):
        #    print("Heuristic:",i,5*(1-dp_H[i, i, dpPrecision]))
        for i in range(n, 0, -1):
            print(
                    tpToPayments(
                            torch.tensor([0 if ii >= i else 1 for ii in range(n)], dtype=torch.float32)
                    )
                )

# %%
def run_dp():
    global decision_offer,decision_welfare,decision_H
    global dp,dp_H,record_ans,utilitya,utilityb
    pdfnumber=[0 for i in range(pdfPrecision+1)];
    cdfnumber=[0 for i in range(pdfPrecision+1)];
    utilitynumber=[0 for i in range(pdfPrecision+1)];
    Possible_utility=[0 for i in range(pdfPrecision+1)];
    utilitya=[0 for i in range(dpPrecision+1)];
    utilityb=[0 for i in range(dpPrecision+1)];
    for i in range(int(trainSize * percentage_train_test)):
        for j in range(n):
            pdfnumber[int(samplesJoint[i,j]*pdfPrecision)]+=1.0/int(trainSize * percentage_train_test*n)
    cdfnumber[0]=pdfnumber[0];
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]
    #print(cdfnumber)  
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]   
    for i in range(0,pdfPrecision+1):
        utilitynumber[i]=0
        for j in range(i,pdfPrecision+1):
            utilitynumber[i]+=pdfnumber[j]*float(j-i)/pdfPrecision
        if(sum(pdfnumber[i:])!=0):
            utilitynumber[i]/=sum(pdfnumber[i:])
    for i in range(0,dpPrecision):
        ii=int(float(i)/dpPrecision*pdfPrecision)
        jj=int(float(i+1)/dpPrecision*pdfPrecision)
        utilitya[i]=(utilitynumber[jj]-utilitynumber[ii])/dpPrecision
        utilityb[i]=utilitynumber[ii]-utilitya[i]*float(i)/dpPrecision
    plt.plot(pdfnumber)
    plt.show()
    print(sum(pdfnumber))

    plt.plot(utilitynumber)
    plt.show()
    
    
    # howManyPpl left, money left, yes already
    dp        = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1])
    decision_offer = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    decision_welfare = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    for yes in range(dpPrecision*n + 1):
        for money in range(dpPrecision + 1):
                offer = float(money) / dpPrecision                                                                     
                dp[1, money, yes] =(1.0 - mydistribution.cdf(offer,order).item()) * (yes/dpPrecision + utilitynumber[round(offer*pdfPrecision)])
                decision_offer[1, money, yes] = money
                decision_welfare[1, money, yes] = int(yes + utilitynumber[round(offer*pdfPrecision)]*dpPrecision)
    for ppl in range(2,  n + 1):
        for yes in range(dpPrecision*n + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -100000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        
                        res = (1 - mydistribution.cdf(offer,order)) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order) * (dp[ppl - 1, money, yes])
                    else:
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        res = (1 - mydistribution.cdf(offer,order,n-ppl).item()) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order,n-ppl).item() * (dp[ppl - 1, money, yes])
                    if maxSoFar < res:
                        maxSoFar = res
                        decision_offer[ppl, money, yes] = offerIndex
                        decision_welfare[ppl, money, yes] = yes_old
                dp[ppl, money, yes] = maxSoFar
    
    print("dp",dp[n, dpPrecision, 0])
    
    def verify_dp(temp,debug):
        if(debug==1):
            print(temp)
        ans =0;
        o_list=[];
        remain_list=[];
        remain=dpPrecision
        record_= 0
        for ppl in range(n,0,-1):
            o=decision_offer[ppl, remain, record_]
            
            #print("record",o,record_)
            if(debug==1):
                print(o,remain,record_)
            o_list.append(o)
            remain_list.append(remain);
            if(o<temp[n-ppl]):
                remain-=int(o);
                record_=decision_welfare[ppl, remain, record_]
                ans=1#+=float(temp[n-ppl]-o)/dpPrecision
                #print("record",record_)
            elif (remain>0):
                ans=0;
        if(remain<=1):
            return ans,o_list;
        else:
            return 0,o_list;
    ans_list=[];
    for i in range(5):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        tempres=verify_dp(temp,1)
        ans_list.append(tempres[0]);
        print(tempres)
        #print("\n",temp)
        #print(plan_dp(temp,1))

    for i in range(10000):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        ans_list.append(verify_dp(temp,0)[0]);
        #print("\n",temp)
        #print(plan_dp(temp))
    print("verify dp vaule:",sum(ans_list)/len(ans_list))
    
    # howManyPpl left, money left, yes already
    dp_H = np.zeros([n + 1 , n + 1, dpPrecision + 1])
    decision_H = np.zeros([n + 1 , n + 1, dpPrecision + 1], dtype=np.uint8)
    # ppl = 0 left
    for i in range(1,n+1):
        for money in range(dpPrecision + 1):
            if money == 0:
                dp_H[i, 0, 0] = 1
            else:
                offer = money / dpPrecision
                dp_H[i, 0, money] = 0#mydistribution.cdf(offer)# + 1.0
    for i in range(1,n+1):
        for ppl in range(1, i + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -1000000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        res = (1-mydistribution.cdf(offer,order)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    else:
                        res = (1-mydistribution.cdf(offer,order,ppl-1)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    if maxSoFar < res.item():
                        maxSoFar = res.item()
                        decision_H[i, ppl, money] = offerIndex
                dp_H[i, ppl, money] = maxSoFar

# %%
def init_weights_xavier_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
def init_weights_xavier_normal(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_normal_(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.1)

# %%
for order in stage:
    samplesJoint=mydistribution.producedata(order,trainSize)
    tp_tensor = torch.tensor(samplesJoint, dtype=torch.float32)
    tp_dataset = TensorDataset(tp_tensor[: int(trainSize * percentage_train_test)])
    tp_dataset_testing = TensorDataset(tp_tensor[int(trainSize * (1.0-percentage_train_test)) :])
    tp_dataloader = DataLoader(tp_dataset, batch_size=128, shuffle=True)
    tp_dataloader_testing = DataLoader(tp_dataset_testing, batch_size=256, shuffle=False)
    run_dp()
    #running
    for order1 in order1name:
        print("Supervised Aim:",order,order1)
        
        # Instantiate the model with hyperparameters
        model = nn.Sequential(
            nn.Linear(n, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, n),
        )
        if(init_weights=="xavier_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="xavier_normal"):
            model.apply(init_weights_xavier_normal)
        if(init_weights=="kaiming_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="kaiming_normal"):
            model.apply(init_weights_xavier_normal)
        # optimizer = optim.SGD(model.parameters(), lr=lr)
        optimizer = optim.Adam(model.parameters(), lr=lr1)
        print(model)
        
        runningLossNN = []
        runningLossCS = []
        runningLossDP = []
        runningLossHeuristic = []
        #model=torch.load("save/pytorchNN=5dp1");
        #model.eval()
        ##order1name=["costsharing","dp","heuristic","random initializing"]
        for epoch in range(1, supervisionEpochs + 1):
#             print("distributionRatio",distributionRatio)
            if(order1=="costsharing"):
                supervisionTrain(epoch, costSharingSupervisionRule)
            elif(order1=="dp"):
                supervisionTrain(epoch, dpSupervisionRule)
            elif(order1=="heuristic"):
                supervisionTrain(epoch, heuristicSupervisionRule)
            elif(order1=="random initializing"):
                print("do nothing");

        test()
        optimizer = optim.Adam(model.parameters(), lr=lr2)
        for epoch in range(1, epochs + 1):
            train(epoch)
            test()
        losslistname.append(order+" "+order1);
        losslist.append(losslisttemp);
        losslisttemp=[];
        savepath="save/pytorchNN=5all-beta"+order+str(order1)
        torch.save(model, savepath);
        print("end")
        print()
# Out:
# beta_a 0.1 beta_b 0.1
# kumaraswamy_a 0.1 kumaraswamy_b 0.3540388371733616
# 0.9999999999999408
# dp 0.3465268611907959
# [49.20997261 49.99999929 24.59383885]
# 24 50 0
# 26 26 22
# 0 0 47
# (1, [24, 26, 0])
# [50.         49.99999609 27.6687652 ]
# 24 50 0
# 26 26 22
# 0 0 47
# (1, [24, 26, 0])
# [4.10112649e+01 7.18185894e-08 5.00000000e+01]
# 24 50 0
# 26 26 22
# 26 26 22
# (1, [24, 26, 26])
# [5.00000000e+01 4.99733577e+01 1.47743668e-07]
# 24 50 0
# 26 26 22
# 0 0 47
# (1, [24, 26, 0])
# [ 1.54160897 48.25514223 29.82712895]
# 24 50 0
# 24 50 0
# 26 26 21
# (1, [24, 24, 26])
# verify dp vaule: 0.5033483258370814
# Supervised Aim: beta dp
# Sequential(
#   (0): Linear(in_features=3, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=3, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.012643
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000234
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000013
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000034
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000056
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000017
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000048
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:105: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:108: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NN 1 : tensor(0.5723)
# CS 1 : 0.5758579093217849
# DP 1 : 0.5726465255081653
# heuristic 1 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.4866, 0.5088, 0.0046])
# tensor([0.4891, 0.5109, 1.0000])
# tensor([1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.775236 testing loss: tensor(0.5724)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.406259 testing loss: tensor(0.5728)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.335616 testing loss: tensor(0.5729)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.361461 testing loss: tensor(0.5728)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 1.439597 testing loss: tensor(0.5727)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 1.548860 testing loss: tensor(0.5727)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.280761 testing loss: tensor(0.5726)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.320051 testing loss: tensor(0.5727)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.224900 testing loss: tensor(0.5727)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.538170 testing loss: tensor(0.5727)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.446833 testing loss: tensor(0.5727)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.477862 testing loss: tensor(0.5727)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 1.399515 testing loss: tensor(0.5727)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.211751 testing loss: tensor(0.5727)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 1.253253 testing loss: tensor(0.5727)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.326968 testing loss: tensor(0.5728)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.235513 testing loss: tensor(0.5728)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.478090 testing loss: tensor(0.5728)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.378061 testing loss: tensor(0.5728)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.243521 testing loss: tensor(0.5728)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.361176 testing loss: tensor(0.5728)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.312906 testing loss: tensor(0.5728)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.556664 testing loss: tensor(0.5728)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 1.233179 testing loss: tensor(0.5728)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 1.447314 testing loss: tensor(0.5728)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 1.468535 testing loss: tensor(0.5728)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.405850 testing loss: tensor(0.5728)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 1.338691 testing loss: tensor(0.5728)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.370854 testing loss: tensor(0.5728)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 1.350716 testing loss: tensor(0.5728)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.354142 testing loss: tensor(0.5728)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.243397 testing loss: tensor(0.5728)
# penalty: 0.0
# NN 2 : tensor(0.5728)
# CS 2 : 0.5758579093217849
# DP 2 : 0.5726465255081653
# heuristic 2 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.5200, 0.4764, 0.0035])
# tensor([0.5210, 0.4790, 1.0000])
# tensor([1., 1., 1.])
# end
#
# Supervised Aim: beta random initializing
# Sequential(
#   (0): Linear(in_features=3, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=3, bias=True)
# )
# do nothing
# NN 1 : tensor(0.5705)
# CS 1 : 0.5758579093217849
# DP 1 : 0.5726465255081653
# heuristic 1 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.2677, 0.1861, 0.5461])
# tensor([0.5801, 0.4199, 1.0000])
# tensor([1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.464124 testing loss: tensor(0.5711)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.539999 testing loss: tensor(0.5723)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.282759 testing loss: tensor(0.5730)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.327196 testing loss: tensor(0.5734)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 1.314849 testing loss: tensor(0.5737)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 1.427522 testing loss: tensor(0.5747)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.297449 testing loss: tensor(0.5751)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.433407 testing loss: tensor(0.5750)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.346573 testing loss: tensor(0.5751)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.498850 testing loss: tensor(0.5757)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.481416 testing loss: tensor(0.5756)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.346333 testing loss: tensor(0.5755)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 1.425200 testing loss: tensor(0.5758)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.243258 testing loss: tensor(0.5759)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 1.414059 testing loss: tensor(0.5759)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.584197 testing loss: tensor(0.5759)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.345060 testing loss: tensor(0.5761)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.517524 testing loss: tensor(0.5760)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.415970 testing loss: tensor(0.5761)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.528087 testing loss: tensor(0.5760)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.334809 testing loss: tensor(0.5759)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.341957 testing loss: tensor(0.5757)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.563599 testing loss: tensor(0.5755)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 1.511375 testing loss: tensor(0.5756)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 1.348333 testing loss: tensor(0.5757)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 1.470443 testing loss: tensor(0.5757)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.366843 testing loss: tensor(0.5758)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 1.448730 testing loss: tensor(0.5758)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.366372 testing loss: tensor(0.5755)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 1.325556 testing loss: tensor(0.5756)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.557660 testing loss: tensor(0.5755)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.295661 testing loss: tensor(0.5755)
# penalty: 0.0
# NN 2 : tensor(0.5754)
# CS 2 : 0.5758579093217849
# DP 2 : 0.5726465255081653
# heuristic 2 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.3244, 0.2792, 0.3964])
# tensor([0.4780, 0.5220, 1.0000])
# tensor([1., 1., 1.])
# end
#
# Supervised Aim: beta costsharing
# Sequential(
#   (0): Linear(in_features=3, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=3, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.001391
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000051
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000001
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000000
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000000
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000000
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000000
# NN 1 : tensor(0.5759)
# CS 1 : 0.5758579093217849
# DP 1 : 0.5726465255081653
# heuristic 1 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.3333, 0.3334, 0.3333])
# tensor([0.5000, 0.5000, 1.0000])
# tensor([1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.416832 testing loss: tensor(0.5759)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.344462 testing loss: tensor(0.5759)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.453007 testing loss: tensor(0.5759)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.310292 testing loss: tensor(0.5759)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 1.535711 testing loss: tensor(0.5759)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 1.539942 testing loss: tensor(0.5758)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.438553 testing loss: tensor(0.5758)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.369647 testing loss: tensor(0.5758)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.544032 testing loss: tensor(0.5758)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.441190 testing loss: tensor(0.5758)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.460048 testing loss: tensor(0.5758)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.444355 testing loss: tensor(0.5758)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 1.301115 testing loss: tensor(0.5757)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.391736 testing loss: tensor(0.5757)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 1.380194 testing loss: tensor(0.5758)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.516704 testing loss: tensor(0.5758)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.337701 testing loss: tensor(0.5757)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.385075 testing loss: tensor(0.5757)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.283044 testing loss: tensor(0.5757)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.444433 testing loss: tensor(0.5757)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.399830 testing loss: tensor(0.5757)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.354153 testing loss: tensor(0.5758)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.349831 testing loss: tensor(0.5758)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 1.207851 testing loss: tensor(0.5758)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 1.442430 testing loss: tensor(0.5757)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 1.415096 testing loss: tensor(0.5757)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.495547 testing loss: tensor(0.5756)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 1.299088 testing loss: tensor(0.5757)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.402137 testing loss: tensor(0.5757)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 1.427975 testing loss: tensor(0.5757)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.429540 testing loss: tensor(0.5756)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.424428 testing loss: tensor(0.5757)
# penalty: 0.0
# NN 2 : tensor(0.5757)
# CS 2 : 0.5758579093217849
# DP 2 : 0.5726465255081653
# heuristic 2 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.3309, 0.3392, 0.3299])
# tensor([0.4932, 0.5068, 1.0000])
# tensor([1., 1., 1.])
# end
#
# Supervised Aim: beta heuristic
# Sequential(
#   (0): Linear(in_features=3, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=3, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.019803
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000300
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000282
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000171
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000025
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000005
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000003
# NN 1 : tensor(0.5718)
# CS 1 : 0.5758579093217849
# DP 1 : 0.5726465255081653
# heuristic 1 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.0043, 0.4977, 0.4980])
# tensor([0.5012, 0.4988, 1.0000])
# tensor([1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 2.102867 testing loss: tensor(0.5717)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.966917 testing loss: tensor(0.5719)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.811202 testing loss: tensor(0.5719)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.892201 testing loss: tensor(0.5722)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 1.947753 testing loss: tensor(0.5722)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 1.657089 testing loss: tensor(0.5722)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.669806 testing loss: tensor(0.5723)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.588099 testing loss: tensor(0.5722)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.410058 testing loss: tensor(0.5721)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.545451 testing loss: tensor(0.5722)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.330897 testing loss: tensor(0.5723)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.582319 testing loss: tensor(0.5722)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 1.635230 testing loss: tensor(0.5721)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.398542 testing loss: tensor(0.5722)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 1.313595 testing loss: tensor(0.5723)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.461767 testing loss: tensor(0.5722)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 1.273151 testing loss: tensor(0.5722)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.272367 testing loss: tensor(0.5723)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 1.206641 testing loss: tensor(0.5722)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.394493 testing loss: tensor(0.5722)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.512586 testing loss: tensor(0.5722)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.238256 testing loss: tensor(0.5722)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.455464 testing loss: tensor(0.5722)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 1.456255 testing loss: tensor(0.5723)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 1.245284 testing loss: tensor(0.5722)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 1.302630 testing loss: tensor(0.5722)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 1.571877 testing loss: tensor(0.5721)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 1.302831 testing loss: tensor(0.5722)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.287347 testing loss: tensor(0.5722)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 1.357712 testing loss: tensor(0.5721)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.457438 testing loss: tensor(0.5722)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.335901 testing loss: tensor(0.5721)
# penalty: 0.0
# NN 2 : tensor(0.5721)
# CS 2 : 0.5758579093217849
# DP 2 : 0.5726465255081653
# heuristic 2 : 0.5725406124353409
# DP: 0.3465268611907959
# tensor([0.0041, 0.4675, 0.5284])
# tensor([0.4880, 0.5120, 1.0000])
# tensor([1., 1., 1.])
# end

# %%
colorlist=["#D2691E",'#4169E1',"#9ACD32","#B22222","#FF00FF","#708090"]
for i in range(len(losslist)):
    plt.plot(losslist[i], '.-', color=colorlist[i], alpha=0.8, label=losslistname[i])

# 显示标签，如果不加这句，即使加了label='一些数字'的参数，最终还是不会显示标签
plt.legend(loc="best")
plt.xlabel('Trianing Times')
plt.ylabel('Welfare')

plt.show()
