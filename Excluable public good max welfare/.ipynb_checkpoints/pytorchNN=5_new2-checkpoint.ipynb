# %%
global n
n = 5
epochs = 1
supervisionEpochs = 1
lr1 = 0.01
lr2 = 0.00002
log_interval = 5
trainSize = 40000#100000
percentage_train_test= 0.5
penaltyLambda = 500
dpPrecision=50
pdfPrecision=100
init_weights="xavier_normal"#"kaiming_uniform""kaiming_normal""xavier_uniform"

# %%
import itertools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import torch.distributions as D
from torch.utils.data import DataLoader, TensorDataset
from pylab import *
from scipy.stats import beta
import math
from localfiles import mydistribution
global samplesJoint,tp_dataloader,tp_dataloader_testing,dp,decision,dp_H,decision_H
global decision_offer,decision_welfare,record_ans

# %%
stage=["twopeak"]
# "twopeak","normal","uniform","independent1","independent2","cauchy","beta","U-exponential","arcsine"
order1name=["dp","random initializing","costsharing","heuristic"]
#order1name=["random initializing1","random initializing2","random initializing3"]
# "costsharing","dp","heuristic","random initializing"

# %%
print(mydistribution)
mydistribution.inital(n)
# Out:
# <module 'localfiles.mydistribution' from 'D:\\coding\\jupyter workplace\\Mechanism Design\\Public Good\\Excluable public good max welfare\\localfiles\\mydistribution.py'>
# 0.3540388371733616

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()
# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU not available, CPU used

# %%
global record_ans
record_ans=0
def recordAndReport(name, source, loss):
    source.append(loss)
    realLength = len(source)
    #print(f"{name} ({realLength}): {loss}")
    print(name,realLength,":" ,loss)

# %%
def bitsToPayments(bits):
    if torch.sum(bits).item() == 0:
        return torch.ones(n)
    bits     = bits.type(torch.float32)
    negBits  = torch.ones(n) - bits
    payments = model(bits)
    payments = payments - 1000 * negBits
    payments = torch.softmax(payments, 0)
    payments = payments + negBits
    return payments

def tpToBits(tp, bits=torch.ones(n).type(torch.uint8)):
    payments = bitsToPayments(bits)
    newBits = (tp >= payments).type(torch.uint8)
    if torch.equal(newBits, bits):
        return bits
    else:
        return tpToBits(tp, newBits)#bits-bits#tpToBits(tp, newBits)

def tpToPayments(tp):
    return bitsToPayments(tpToBits(tp))


def tpToTotalWelfare(tp):
    return torch.max(torch.tensor(0.0),torch.dot(tp,tpToBits(tp).type(torch.float32))-1.0)

# %%
def dpSupervisionRule(tp):
    global decision_offer,decision_welfare
    global record_ans
    global  dp,decision
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    money = dpPrecision
    record_=0
    for i in range(n):
        offerIndex = decision_offer[n - i, money,record_]
        offer = float(offerIndex) / dpPrecision
        if tp[i] > offer:
            money -= offerIndex
            bits[i] = 1
            record_ = decision_welfare[n - i, money, record_]
            payments[i] = offer
        else:
            bits[i] = 0
            payments[i] = 1
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
#     print()
#     print(tp)
#     print(bits)
#     print(payments)
#     print()
    return (bits, payments)


def heuristicSupervisionRule(tp):
    global  dp_H,decision_H
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    tempold=-1;
    for turns in range(n,0,-1):
        money = dpPrecision
        j=0
        tempo=sum(bits)
        #print("bits",tempo)
        for i in range(n):
            if(j>=n):
                break;
            
            offerIndex = decision_H[tempo ,tempo - i, money]
            offer = float(offerIndex) / dpPrecision
            while(j<n):
                if(bits[j]!=0):
                    break;
                j+=1;
            if(j>=n):
                break;
            if tp[j] >= offer:
                #print(money,j,tp[j],offer)
                money -= offerIndex
                bits[j] = 1
                payments[j] = offer
            else:
                bits[j] = 0;
                payments[j] = 1.0;
            j+=1;
        #print("money",money)
        if(money==0 and tempold==tempo):
            break;
        tempold=tempo;
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]

    bits = torch.tensor(bits, dtype=torch.float32)
    payments = torch.tensor(payments, dtype=torch.float32)
    # print()
    # print(tp)
    # print(bits)
    # print(payments)
    # print()
    return (bits, payments)



def costSharingSupervisionRule(tp):
    tp = list(tp.numpy())
    for k in range(n, -1, -1):
        if k == 0:
            break
        bits = [1 if tp[ii] >= 1.0 / k else 0 for ii in range(n)]
        if sum(bits) == k:
            break
    if k == 0:
        bits = [0 for ii in range(n)]
        payments = [1 for ii in range(n)]
    else:
        payments = [1.0 / k if bits[ii] == 1 else 1 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
    return (bits, payments)

    
def costSharingWelfare(tp):
    #print(tp,costSharingSupervisionRule(tp)[0])
    return max(0.0,float(torch.dot(tp,torch.tensor(costSharingSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def dpWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(dpSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def heuristicWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(heuristicSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def tpToTotalDelay(tp):
    return n - torch.sum(tpToBits(tp).type(torch.float32))

# %%
def supervisionTrain(epoch, supervisionRule):
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss = penalty * penaltyLambda /100000
        
        for tp in tp_batch:
            bits, payments = supervisionRule(tp)
            loss += F.mse_loss(bitsToPayments(bits), payments)

        loss = loss / len(tp_batch)
        loss.backward()
        optimizer.step()
        if batch_idx % (log_interval*5) == 0:
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                )
            )

losslist=[];
losslistname=[];
losslisttemp=[];
def test_batch():
    global losslisttemp; 
    model.eval()
    with torch.no_grad():
        lenLoss= 0
        nnLoss = 0
        for (tp_batch,) in tp_dataloader_testing:
            for tp in tp_batch:
                nnLoss += tpToTotalWelfare(tp)
            lenLoss+=len(tp_batch)
        nnLoss/=lenLoss
    return nnLoss


def train(epoch):
    global record_ans
    global losslisttemp; 
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        loss=0;
        for tp in tp_batch:
            for i in range(n):
                tp1 = tp.clone()
                tp1[i] = 1
                tp0 = tp.clone()
                tp0[i] = 0
                offer = tpToPayments(tp1)[i]
                Welfare1 = tpToTotalWelfare(tp1)
                Welfare0 = tpToTotalWelfare(tp0)
                offerIndex=int(offer*dpPrecision)
                if(order!="independent1" and order!="independent2"):
                    losspart2= (utilitya[offerIndex]*offer+utilityb[offerIndex])*1
                    loss -= (1 - mydistribution.cdf(offer,order)) * (Welfare1+losspart2-losspart2.item()) + mydistribution.cdf(offer,order) * Welfare0
                else:
                    loss -= (1 - mydistribution.cdf(offer,order,i)) * Welfare1 + mydistribution.cdf(offer,order,i) * Welfare0
                    
                Delay1 = tpToTotalDelay(tp1)
                Delay0 = tpToTotalDelay(tp0)
                if(order!="independent1" and order!="independent2"):
                    loss += (1 - mydistribution.cdf(offer,order)) * Delay1 + mydistribution.cdf(offer,order) * Delay0
                else:
                    loss += (1 - mydistribution.cdf(offer,order,i)) * Delay1 + mydistribution.cdf(offer,order,i) * Delay0
        loss = loss / len(tp_batch) / n
        
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss += penalty * penaltyLambda
        
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            losstemp=test_batch();
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                ),"testing loss:",losstemp
            )
            losslisttemp.append(losstemp);
            
    print("penalty:",penalty.item())
    
allBits = [torch.tensor(bits, dtype=torch.int16) for bits in itertools.product([0, 1], repeat=n)]

def test():
    global record_ans
    global losslisttemp; 
    model.eval()

    with torch.no_grad():
        costSharingLoss = 0
        dpLoss = 0
        nnLoss = 0
        heuristicLoss=0
        lenLoss= 0
        for (tp_batch,) in tp_dataloader_testing:

            for tp in tp_batch:
                costSharingLoss += costSharingWelfare(tp)
                dpLoss += dpWelfare(tp)
                nnLoss += tpToTotalWelfare(tp)
                heuristicLoss+= heuristicWelfare(tp)
            lenLoss+=len(tp_batch)
        costSharingLoss /= lenLoss
        dpLoss /= lenLoss
        nnLoss /= lenLoss
        heuristicLoss /= lenLoss
        #print(lenLoss)
        losslisttemp.append(nnLoss);
        recordAndReport("NN", runningLossNN, nnLoss)
        recordAndReport("CS", runningLossCS, costSharingLoss)
        recordAndReport("DP", runningLossDP, dpLoss)
        recordAndReport("heuristic", runningLossHeuristic, heuristicLoss)
        print("DP:",dp[n, dpPrecision,0])
        #for i in range(n, 0, -1):
        #    print("Heuristic:",i,5*(1-dp_H[i, i, dpPrecision]))
        for i in range(n, 0, -1):
            print(
                    tpToPayments(
                            torch.tensor([0 if ii >= i else 1 for ii in range(n)], dtype=torch.float32)
                    )
                )

# %%
def run_dp():
    global decision_offer,decision_welfare,decision_H
    global dp,dp_H,record_ans,utilitya,utilityb
    pdfnumber=[0 for i in range(pdfPrecision+1)];
    cdfnumber=[0 for i in range(pdfPrecision+1)];
    utilitynumber=[0 for i in range(pdfPrecision+1)];
    Possible_utility=[0 for i in range(pdfPrecision+1)];
    utilitya=[0 for i in range(dpPrecision+1)];
    utilityb=[0 for i in range(dpPrecision+1)];
    for i in range(int(trainSize * percentage_train_test)):
        for j in range(n):
            pdfnumber[int(samplesJoint[i,j]*pdfPrecision)]+=1.0/int(trainSize * percentage_train_test*n)
    cdfnumber[0]=pdfnumber[0];
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]
    #print(cdfnumber)  
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]   
    for i in range(0,pdfPrecision+1):
        utilitynumber[i]=0
        for j in range(i,pdfPrecision+1):
            utilitynumber[i]+=pdfnumber[j]*float(j-i)/pdfPrecision
        if(sum(pdfnumber[i:])!=0):
            utilitynumber[i]/=sum(pdfnumber[i:])
    for i in range(0,dpPrecision):
        ii=int(float(i)/dpPrecision*pdfPrecision)
        jj=int(float(i+1)/dpPrecision*pdfPrecision)
        utilitya[i]=(utilitynumber[jj]-utilitynumber[ii])/dpPrecision
        utilityb[i]=utilitynumber[ii]-utilitya[i]*float(i)/dpPrecision
    plt.plot(pdfnumber)
    plt.show()
    print(sum(pdfnumber))

    plt.plot(utilitynumber)
    plt.show()
    
    
    # howManyPpl left, money left, yes already
    dp        = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1])
    decision_offer = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    decision_welfare = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    for yes in range(dpPrecision*n + 1):
        for money in range(dpPrecision + 1):
                offer = float(money) / dpPrecision                                                                     
                dp[1, money, yes] =(1.0 - mydistribution.cdf(offer,order).item()) * (yes/dpPrecision + utilitynumber[round(offer*pdfPrecision)])
                decision_offer[1, money, yes] = money
                decision_welfare[1, money, yes] = int(yes + utilitynumber[round(offer*pdfPrecision)]*dpPrecision)
    for ppl in range(2,  n + 1):
        for yes in range(dpPrecision*n + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -100000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        
                        res = (1 - mydistribution.cdf(offer,order)) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order) * (dp[ppl - 1, money, yes])
                    else:
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        res = (1 - mydistribution.cdf(offer,order,n-ppl).item()) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order,n-ppl).item() * (dp[ppl - 1, money, yes])
                    if maxSoFar < res:
                        maxSoFar = res
                        decision_offer[ppl, money, yes] = offerIndex
                        decision_welfare[ppl, money, yes] = yes_old
                dp[ppl, money, yes] = maxSoFar
    
    print("dp",dp[n, dpPrecision, 0])
    
    def verify_dp(temp,debug):
        if(debug==1):
            print(temp)
        ans =0;
        o_list=[];
        remain_list=[];
        remain=dpPrecision
        record_= 0
        for ppl in range(n,0,-1):
            o=decision_offer[ppl, remain, record_]
            
            #print("record",o,record_)
            if(debug==1):
                print(o,remain,record_)
            o_list.append(o)
            remain_list.append(remain);
            if(o<temp[n-ppl]):
                remain-=int(o);
                record_=decision_welfare[ppl, remain, record_]
                ans=1#+=float(temp[n-ppl]-o)/dpPrecision
                #print("record",record_)
            elif (remain>0):
                ans=0;
        if(remain<=1):
            return ans,o_list;
        else:
            return 0,o_list;
    ans_list=[];
    for i in range(5):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        tempres=verify_dp(temp,1)
        ans_list.append(tempres[0]);
        print(tempres)
        #print("\n",temp)
        #print(plan_dp(temp,1))

    for i in range(10000):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        ans_list.append(verify_dp(temp,0)[0]);
        #print("\n",temp)
        #print(plan_dp(temp))
    print("verify dp vaule:",sum(ans_list)/len(ans_list))
    
    # howManyPpl left, money left, yes already
    dp_H = np.zeros([n + 1 , n + 1, dpPrecision + 1])
    decision_H = np.zeros([n + 1 , n + 1, dpPrecision + 1], dtype=np.uint8)
    # ppl = 0 left
    for i in range(1,n+1):
        for money in range(dpPrecision + 1):
            if money == 0:
                dp_H[i, 0, 0] = 1
            else:
                offer = money / dpPrecision
                dp_H[i, 0, money] = 0#mydistribution.cdf(offer)# + 1.0
    for i in range(1,n+1):
        for ppl in range(1, i + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -1000000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        res = (1-mydistribution.cdf(offer,order)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    else:
                        res = (1-mydistribution.cdf(offer,order,ppl-1)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    if maxSoFar < res.item():
                        maxSoFar = res.item()
                        decision_H[i, ppl, money] = offerIndex
                dp_H[i, ppl, money] = maxSoFar

# %%
def init_weights_xavier_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
def init_weights_xavier_normal(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_normal_(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.1)

# %%
for order in stage:
    samplesJoint=mydistribution.producedata(order,trainSize)
    tp_tensor = torch.tensor(samplesJoint, dtype=torch.float32)
    tp_dataset = TensorDataset(tp_tensor[: int(trainSize * percentage_train_test)])
    tp_dataset_testing = TensorDataset(tp_tensor[int(trainSize * (1.0-percentage_train_test)) :])
    tp_dataloader = DataLoader(tp_dataset, batch_size=128, shuffle=True)
    tp_dataloader_testing = DataLoader(tp_dataset_testing, batch_size=256, shuffle=False)
    run_dp()
    #running
    for order1 in order1name:
        print("Supervised Aim:",order,order1)
        
        # Instantiate the model with hyperparameters
        model = nn.Sequential(
            nn.Linear(n, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, n),
        )
        if(init_weights=="xavier_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="xavier_normal"):
            model.apply(init_weights_xavier_normal)
        if(init_weights=="kaiming_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="kaiming_normal"):
            model.apply(init_weights_xavier_normal)
        # optimizer = optim.SGD(model.parameters(), lr=lr)
        optimizer = optim.Adam(model.parameters(), lr=lr1)
        print(model)
        
        runningLossNN = []
        runningLossCS = []
        runningLossDP = []
        runningLossHeuristic = []
        #model=torch.load("save/pytorchNN=5dp1");
        #model.eval()
        ##order1name=["costsharing","dp","heuristic","random initializing"]
        for epoch in range(1, supervisionEpochs + 1):
#             print("distributionRatio",distributionRatio)
            if(order1=="costsharing"):
                supervisionTrain(epoch, costSharingSupervisionRule)
            elif(order1=="dp"):
                supervisionTrain(epoch, dpSupervisionRule)
            elif(order1=="heuristic"):
                supervisionTrain(epoch, heuristicSupervisionRule)
            elif(order1=="random initializing"):
                print("do nothing");

        test()
        optimizer = optim.Adam(model.parameters(), lr=lr2)
        for epoch in range(1, epochs + 1):
            train(epoch)
            test()
        losslistname.append(order+" "+order1);
        losslist.append(losslisttemp);
        losslisttemp=[];
        savepath="save/pytorchNN=5all-beta"+order+str(order1)
        torch.save(model, savepath);
        print("end")
        print()
# Out:
# loc 0.15 scale 0.1
# loc 0.85 scale 0.1
# 0.9999999999999719
# dp 1.2850109338760376
# [41.86931821 41.54067131 44.1648435   6.63638656 12.52269995]
# 32 50 0
# 8 18 24
# 8 10 47
# 2 2 71
# 0 0 96
# (1, [32, 8, 8, 2, 0])
# [44.69264209 38.59493424  8.88272681  9.02892503 40.06883423]
# 32 50 0
# 8 18 24
# 8 10 47
# 2 2 71
# 0 0 96
# (1, [32, 8, 8, 2, 0])
# [ 6.19404006 12.48851497 47.46406659 10.45101147  4.72405278]
# 32 50 0
# 21 50 0
# 21 50 0
# 29 29 15
# 29 29 15
# (0, [32, 21, 21, 29, 29])
# [37.86894818 45.82480656 10.43833296 16.72450033  7.03386036]
# 32 50 0
# 8 18 24
# 8 10 47
# 2 2 71
# 0 0 96
# (1, [32, 8, 8, 2, 0])
# [ 7.91824431 43.57549286 44.87107771  1.84474026  3.77089286]
# 32 50 0
# 21 50 0
# 27 29 17
# 2 2 41
# 2 2 41
# (1, [32, 21, 27, 2, 2])
# verify dp vaule: 0.8154922538730635
# Supervised Aim: twopeak dp
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.033293
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000596
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000115
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000078
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000045
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000032
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000029
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:105: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:108: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NN 1 : tensor(1.2918)
# CS 1 : 1.2345223080515861
# DP 1 : 1.2862644815087318
# heuristic 1 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([6.4177e-01, 1.6083e-01, 1.5742e-01, 3.9748e-02, 2.3590e-04])
# tensor([0.6456, 0.1677, 0.1474, 0.0393, 1.0000])
# tensor([0.6702, 0.1727, 0.1571, 1.0000, 1.0000])
# tensor([0.7845, 0.2155, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 11.831693 testing loss: tensor(1.2916)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 10.624716 testing loss: tensor(1.2909)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 9.630700 testing loss: tensor(1.2901)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 8.308344 testing loss: tensor(1.2894)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 7.589221 testing loss: tensor(1.2893)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 6.327861 testing loss: tensor(1.2892)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 5.655204 testing loss: tensor(1.2891)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 5.332111 testing loss: tensor(1.2888)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 4.816928 testing loss: tensor(1.2889)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 4.888184 testing loss: tensor(1.2888)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 4.543653 testing loss: tensor(1.2891)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 4.245754 testing loss: tensor(1.2894)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 4.254699 testing loss: tensor(1.2896)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 4.111990 testing loss: tensor(1.2897)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 3.828120 testing loss: tensor(1.2899)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 3.707655 testing loss: tensor(1.2900)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 3.891502 testing loss: tensor(1.2901)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 3.941009 testing loss: tensor(1.2901)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 3.332125 testing loss: tensor(1.2900)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 2.990310 testing loss: tensor(1.2900)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 3.363268 testing loss: tensor(1.2899)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 3.465772 testing loss: tensor(1.2899)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 3.018695 testing loss: tensor(1.2901)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 2.606282 testing loss: tensor(1.2902)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 2.887888 testing loss: tensor(1.2901)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 2.807769 testing loss: tensor(1.2903)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 2.844929 testing loss: tensor(1.2903)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 2.641406 testing loss: tensor(1.2904)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 2.757839 testing loss: tensor(1.2905)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 2.593034 testing loss: tensor(1.2903)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 2.208673 testing loss: tensor(1.2904)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 2.699800 testing loss: tensor(1.2904)
# penalty: 0.2055118978023529
# NN 2 : tensor(1.2904)
# CS 2 : 1.2345223080515861
# DP 2 : 1.2862644815087318
# heuristic 2 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([6.5559e-01, 1.5481e-01, 1.5509e-01, 3.4365e-02, 1.4825e-04])
# tensor([0.6520, 0.1590, 0.1508, 0.0382, 1.0000])
# tensor([0.6700, 0.1679, 0.1621, 1.0000, 1.0000])
# tensor([0.7813, 0.2187, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak random initializing
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# do nothing
# NN 1 : tensor(1.2380)
# CS 1 : 1.2345223080515861
# DP 1 : 1.2862644815087318
# heuristic 1 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([0.2607, 0.1676, 0.1841, 0.1717, 0.2158])
# tensor([0.3197, 0.2451, 0.2319, 0.2033, 1.0000])
# tensor([0.3743, 0.3285, 0.2972, 1.0000, 1.0000])
# tensor([0.5197, 0.4803, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.148946 testing loss: tensor(1.2383)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.006595 testing loss: tensor(1.2406)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 0.836339 testing loss: tensor(1.2432)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 1.118293 testing loss: tensor(1.2470)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 0.905964 testing loss: tensor(1.2513)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.825495 testing loss: tensor(1.2562)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 0.980813 testing loss: tensor(1.2611)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 0.666805 testing loss: tensor(1.2665)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 0.471222 testing loss: tensor(1.2732)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 0.530818 testing loss: tensor(1.2797)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.599958 testing loss: tensor(1.2853)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 0.664803 testing loss: tensor(1.2909)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 0.589719 testing loss: tensor(1.2943)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: -0.086347 testing loss: tensor(1.2953)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 0.453376 testing loss: tensor(1.2945)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.493035 testing loss: tensor(1.2940)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 0.360460 testing loss: tensor(1.2937)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 0.282841 testing loss: tensor(1.2926)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 0.312656 testing loss: tensor(1.2904)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 0.526249 testing loss: tensor(1.2893)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.638037 testing loss: tensor(1.2884)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 0.474515 testing loss: tensor(1.2883)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 0.524688 testing loss: tensor(1.2887)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 0.066920 testing loss: tensor(1.2893)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 0.493465 testing loss: tensor(1.2896)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.110782 testing loss: tensor(1.2899)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 0.361347 testing loss: tensor(1.2905)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 0.253164 testing loss: tensor(1.2908)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 0.245254 testing loss: tensor(1.2919)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 0.405095 testing loss: tensor(1.2921)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.460322 testing loss: tensor(1.2921)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 0.304393 testing loss: tensor(1.2925)
# penalty: 0.0
# NN 2 : tensor(1.2925)
# CS 2 : 1.2345223080515861
# DP 2 : 1.2862644815087318
# heuristic 2 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([0.6751, 0.0966, 0.0527, 0.0558, 0.1197])
# tensor([0.7389, 0.1351, 0.0620, 0.0640, 1.0000])
# tensor([0.7445, 0.1707, 0.0849, 1.0000, 1.0000])
# tensor([0.7978, 0.2022, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak costsharing
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.001591
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000020
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000002
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000000
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000000
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000000
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000000
# NN 1 : tensor(1.2346)
# CS 1 : 1.2345223080515861
# DP 1 : 1.2862644815087318
# heuristic 1 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([0.1998, 0.2001, 0.1999, 0.2002, 0.2000])
# tensor([0.2503, 0.2492, 0.2498, 0.2507, 1.0000])
# tensor([0.3337, 0.3330, 0.3333, 1.0000, 1.0000])
# tensor([0.5002, 0.4998, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.036457 testing loss: tensor(1.2346)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.080161 testing loss: tensor(1.2348)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.002534 testing loss: tensor(1.2348)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 0.974557 testing loss: tensor(1.2349)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 0.976985 testing loss: tensor(1.2349)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.872122 testing loss: tensor(1.2349)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 0.871163 testing loss: tensor(1.2348)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 0.813824 testing loss: tensor(1.2349)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 0.876758 testing loss: tensor(1.2350)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.061299 testing loss: tensor(1.2350)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 1.059236 testing loss: tensor(1.2349)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 0.870435 testing loss: tensor(1.2350)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 0.905810 testing loss: tensor(1.2351)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 1.201116 testing loss: tensor(1.2350)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 0.912868 testing loss: tensor(1.2352)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.096111 testing loss: tensor(1.2351)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 0.962444 testing loss: tensor(1.2352)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 0.887455 testing loss: tensor(1.2353)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 0.648917 testing loss: tensor(1.2353)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 1.152748 testing loss: tensor(1.2352)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.914940 testing loss: tensor(1.2353)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.065832 testing loss: tensor(1.2354)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 1.254360 testing loss: tensor(1.2353)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 1.155708 testing loss: tensor(1.2354)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 0.863644 testing loss: tensor(1.2356)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 1.264613 testing loss: tensor(1.2355)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 0.871276 testing loss: tensor(1.2354)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 0.900051 testing loss: tensor(1.2354)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 1.015731 testing loss: tensor(1.2355)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 0.996385 testing loss: tensor(1.2355)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.958282 testing loss: tensor(1.2356)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 1.017684 testing loss: tensor(1.2356)
# penalty: 0.0
# NN 2 : tensor(1.2356)
# CS 2 : 1.2345223080515861
# DP 2 : 1.2862644815087318
# heuristic 2 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([0.2094, 0.1973, 0.1896, 0.2046, 0.1991])
# tensor([0.2613, 0.2459, 0.2369, 0.2560, 1.0000])
# tensor([0.3496, 0.3306, 0.3198, 1.0000, 1.0000])
# tensor([0.5146, 0.4854, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak heuristic
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.049593
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000631
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000167
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000045
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000011
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000020
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000011
# NN 1 : tensor(1.3019)
# CS 1 : 1.2345223080515861
# DP 1 : 1.2862644815087318
# heuristic 1 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([0.0601, 0.0817, 0.0827, 0.0817, 0.6938])
# tensor([0.0801, 0.1020, 0.1012, 0.7167, 1.0000])
# tensor([0.1195, 0.1398, 0.7407, 1.0000, 1.0000])
# tensor([0.4982, 0.5018, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 28.747681 testing loss: tensor(1.3031)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 27.609039 testing loss: tensor(1.3068)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 26.459930 testing loss: tensor(1.3105)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 25.581221 testing loss: tensor(1.3145)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 24.550980 testing loss: tensor(1.3171)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 23.476725 testing loss: tensor(1.3189)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 22.143353 testing loss: tensor(1.3211)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 21.387800 testing loss: tensor(1.3231)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 19.889818 testing loss: tensor(1.3239)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 18.793121 testing loss: tensor(1.3247)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 17.932728 testing loss: tensor(1.3248)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 17.277321 testing loss: tensor(1.3247)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 16.127321 testing loss: tensor(1.3248)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 14.854548 testing loss: tensor(1.3238)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 13.988434 testing loss: tensor(1.3233)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 12.588788 testing loss: tensor(1.3223)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 11.328530 testing loss: tensor(1.3212)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 10.811831 testing loss: tensor(1.3199)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 9.190726 testing loss: tensor(1.3187)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 8.770637 testing loss: tensor(1.3172)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 7.814152 testing loss: tensor(1.3164)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 6.987315 testing loss: tensor(1.3149)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 6.099849 testing loss: tensor(1.3133)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 5.425867 testing loss: tensor(1.3119)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 4.548743 testing loss: tensor(1.3108)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 3.969134 testing loss: tensor(1.3092)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 3.432075 testing loss: tensor(1.3080)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 2.682976 testing loss: tensor(1.3074)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 2.784082 testing loss: tensor(1.3072)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 2.319711 testing loss: tensor(1.3068)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 2.137432 testing loss: tensor(1.3065)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 2.152752 testing loss: tensor(1.3062)
# penalty: 0.1577281653881073
# NN 2 : tensor(1.3061)
# CS 2 : 1.2345223080515861
# DP 2 : 1.2862644815087318
# heuristic 2 : 1.2817831569850444
# DP: 1.2850109338760376
# tensor([0.0759, 0.1183, 0.1155, 0.0927, 0.5976])
# tensor([0.1488, 0.2209, 0.1931, 0.4372, 1.0000])
# tensor([0.2220, 0.2854, 0.4926, 1.0000, 1.0000])
# tensor([0.4693, 0.5307, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end

# %%
colorlist=["#D2691E",'#4169E1',"#9ACD32","#B22222","#FF00FF","#708090"]
for i in range(len(losslist)):
    plt.plot(losslist[i], '.-', color=colorlist[i], alpha=0.8, label=losslistname[i])

# 显示标签，如果不加这句，即使加了label='一些数字'的参数，最终还是不会显示标签
plt.legend(loc="best")
plt.xlabel('Trianing Times')
plt.ylabel('Welfare')

plt.show()
