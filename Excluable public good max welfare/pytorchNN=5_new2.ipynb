# %%
global n
n = 5
epochs = 1
supervisionEpochs = 1
lr1 = 0.01
lr2 = 0.00002
log_interval = 5
trainSize = 40000#100000
percentage_train_test= 0.5
penaltyLambda = 500
dpPrecision=50
pdfPrecision=100
init_weights="xavier_normal"#"kaiming_uniform""kaiming_normal""xavier_uniform"

# %%
import itertools
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import torch.distributions as D
from torch.utils.data import DataLoader, TensorDataset
from pylab import *
from scipy.stats import beta
import math
from localfiles import mydistribution
global samplesJoint,tp_dataloader,tp_dataloader_testing,dp,decision,dp_H,decision_H
global decision_offer,decision_welfare,record_ans

# %%
stage=["twopeak"]
# "twopeak","normal","uniform","independent1","independent2","cauchy","beta","U-exponential","arcsine"
order1name=["dp","random initializing","costsharing","heuristic"]
#order1name=["random initializing1","random initializing2","random initializing3"]
# "costsharing","dp","heuristic","random initializing"

# %%
print(mydistribution)
mydistribution.inital(n)
# Out:
# <module 'localfiles.mydistribution' from 'D:\\coding\\jupyter workplace\\Mechanism Design\\Public Good\\Excluable public good max welfare\\localfiles\\mydistribution.py'>
# 0.3540388371733616

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()
# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU not available, CPU used

# %%
global record_ans
record_ans=0
def recordAndReport(name, source, loss):
    source.append(loss)
    realLength = len(source)
    #print(f"{name} ({realLength}): {loss}")
    print(name,realLength,":" ,loss)

# %%
def bitsToPayments(bits):
    if torch.sum(bits).item() == 0:
        return torch.ones(n)
    bits     = bits.type(torch.float32)
    negBits  = torch.ones(n) - bits
    payments = model(bits)
    payments = payments - 1000 * negBits
    payments = torch.softmax(payments, 0)
    payments = payments + negBits
    return payments

def tpToBits(tp, bits=torch.ones(n).type(torch.uint8)):
    payments = bitsToPayments(bits)
    newBits = (tp >= payments).type(torch.uint8)
    if torch.equal(newBits, bits):
        return bits
    else:
        return tpToBits(tp, newBits)#bits-bits#tpToBits(tp, newBits)

def tpToPayments(tp):
    return bitsToPayments(tpToBits(tp))


def tpToTotalWelfare(tp):
    return torch.max(torch.tensor(0.0),torch.dot(tp,tpToBits(tp).type(torch.float32))-1.0)

# %%
def dpSupervisionRule(tp):
    global decision_offer,decision_welfare
    global record_ans
    global  dp,decision
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    money = dpPrecision
    record_=0
    for i in range(n):
        offerIndex = decision_offer[n - i, money,record_]
        offer = float(offerIndex) / dpPrecision
        if tp[i] > offer:
            money -= offerIndex
            bits[i] = 1
            record_ = decision_welfare[n - i, money, record_]
            payments[i] = offer
        else:
            bits[i] = 0
            payments[i] = 1
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
#     print()
#     print(tp)
#     print(bits)
#     print(payments)
#     print()
    return (bits, payments)


def heuristicSupervisionRule(tp):
    global  dp_H,decision_H
    tp = list(tp.numpy())
    bits = [1 for ii in range(n)]
    payments = [0.0 for ii in range(n)]
    tempold=-1;
    for turns in range(n,0,-1):
        money = dpPrecision
        j=0
        tempo=sum(bits)
        #print("bits",tempo)
        for i in range(n):
            if(j>=n):
                break;
            
            offerIndex = decision_H[tempo ,tempo - i, money]
            offer = float(offerIndex) / dpPrecision
            while(j<n):
                if(bits[j]!=0):
                    break;
                j+=1;
            if(j>=n):
                break;
            if tp[j] >= offer:
                #print(money,j,tp[j],offer)
                money -= offerIndex
                bits[j] = 1
                payments[j] = offer
            else:
                bits[j] = 0;
                payments[j] = 1.0;
            j+=1;
        #print("money",money)
        if(money==0 and tempold==tempo):
            break;
        tempold=tempo;
    if money > 0:
        bits = [0 for ii in range(n)]
        payments = [1.0 for ii in range(n)]

    bits = torch.tensor(bits, dtype=torch.float32)
    payments = torch.tensor(payments, dtype=torch.float32)
    # print()
    # print(tp)
    # print(bits)
    # print(payments)
    # print()
    return (bits, payments)



def costSharingSupervisionRule(tp):
    tp = list(tp.numpy())
    for k in range(n, -1, -1):
        if k == 0:
            break
        bits = [1 if tp[ii] >= 1.0 / k else 0 for ii in range(n)]
        if sum(bits) == k:
            break
    if k == 0:
        bits = [0 for ii in range(n)]
        payments = [1 for ii in range(n)]
    else:
        payments = [1.0 / k if bits[ii] == 1 else 1 for ii in range(n)]
    bits = torch.tensor(bits, dtype=torch.uint8)
    payments = torch.tensor(payments, dtype=torch.float32)
    return (bits, payments)

    
def costSharingWelfare(tp):
    #print(tp,costSharingSupervisionRule(tp)[0])
    return max(0.0,float(torch.dot(tp,torch.tensor(costSharingSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def dpWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(dpSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def heuristicWelfare(tp):
    return max(0.0,float(torch.dot(tp,torch.tensor(heuristicSupervisionRule(tp)[0],dtype=torch.float32)).item()-1.0))

def tpToTotalDelay(tp):
    return n - torch.sum(tpToBits(tp).type(torch.float32))

# %%
def supervisionTrain(epoch, supervisionRule):
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss = penalty * penaltyLambda /100000
        
        for tp in tp_batch:
            bits, payments = supervisionRule(tp)
            loss += F.mse_loss(bitsToPayments(bits), payments)

        loss = loss / len(tp_batch)
        loss.backward()
        optimizer.step()
        if batch_idx % (log_interval*5) == 0:
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                )
            )

losslist=[];
losslistname=[];
losslisttemp=[];
def test_batch():
    global losslisttemp; 
    model.eval()
    with torch.no_grad():
        lenLoss= 0
        nnLoss = 0
        for (tp_batch,) in tp_dataloader_testing:
            for tp in tp_batch:
                nnLoss += tpToTotalWelfare(tp)
            lenLoss+=len(tp_batch)
        nnLoss/=lenLoss
    return nnLoss


def train(epoch):
    global record_ans
    global losslisttemp; 
    model.train()
    for batch_idx, (tp_batch,) in enumerate(tp_dataloader):
        optimizer.zero_grad()
        loss=0;
        for tp in tp_batch:
            for i in range(n):
                tp1 = tp.clone()
                tp1[i] = 1
                tp0 = tp.clone()
                tp0[i] = 0
                offer = tpToPayments(tp1)[i]
                Welfare1 = tpToTotalWelfare(tp1)
                Welfare0 = tpToTotalWelfare(tp0)
                offerIndex=int(offer*dpPrecision)
                if(order!="independent1" and order!="independent2"):
                    losspart2= (utilitya[offerIndex]*offer+utilityb[offerIndex])*1
                    loss -= (1 - mydistribution.cdf(offer,order)) * (Welfare1+losspart2-losspart2.item()) + mydistribution.cdf(offer,order) * Welfare0
                else:
                    loss -= (1 - mydistribution.cdf(offer,order,i)) * Welfare1 + mydistribution.cdf(offer,order,i) * Welfare0
                    
                Delay1 = tpToTotalDelay(tp1)
                Delay0 = tpToTotalDelay(tp0)
                if(order!="independent1" and order!="independent2"):
                    loss += (1 - mydistribution.cdf(offer,order)) * Delay1 + mydistribution.cdf(offer,order) * Delay0
                else:
                    loss += (1 - mydistribution.cdf(offer,order,i)) * Delay1 + mydistribution.cdf(offer,order,i) * Delay0
        loss = loss / len(tp_batch) / n
        
        penalty = 0
        for bitsMoreOnes in allBits:
            for i in range(n):
                if bitsMoreOnes[i] == 1:
                    bitsLessOnes = bitsMoreOnes.clone()
                    bitsLessOnes[i] = 0
                    penalty = penalty + torch.sum(
                        torch.relu(
                            bitsToPayments(bitsMoreOnes) - bitsToPayments(bitsLessOnes)
                        )
                    )
        loss += penalty * penaltyLambda
        
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            losstemp=test_batch();
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(tp_batch),
                    len(tp_dataloader.dataset),
                    100.0 * batch_idx / len(tp_dataloader),
                    loss.item(),
                ),"testing loss:",losstemp
            )
            losslisttemp.append(losstemp);
            
    print("penalty:",penalty.item())
    
allBits = [torch.tensor(bits, dtype=torch.int16) for bits in itertools.product([0, 1], repeat=n)]

def test():
    global record_ans
    global losslisttemp; 
    model.eval()

    with torch.no_grad():
        costSharingLoss = 0
        dpLoss = 0
        nnLoss = 0
        heuristicLoss=0
        lenLoss= 0
        for (tp_batch,) in tp_dataloader_testing:

            for tp in tp_batch:
                costSharingLoss += costSharingWelfare(tp)
                dpLoss += dpWelfare(tp)
                nnLoss += tpToTotalWelfare(tp)
                heuristicLoss+= heuristicWelfare(tp)
            lenLoss+=len(tp_batch)
        costSharingLoss /= lenLoss
        dpLoss /= lenLoss
        nnLoss /= lenLoss
        heuristicLoss /= lenLoss
        #print(lenLoss)
        losslisttemp.append(nnLoss);
        recordAndReport("NN", runningLossNN, nnLoss)
        recordAndReport("CS", runningLossCS, costSharingLoss)
        recordAndReport("DP", runningLossDP, dpLoss)
        recordAndReport("heuristic", runningLossHeuristic, heuristicLoss)
        print("DP:",dp[n, dpPrecision,0])
        #for i in range(n, 0, -1):
        #    print("Heuristic:",i,5*(1-dp_H[i, i, dpPrecision]))
        for i in range(n, 0, -1):
            print(
                    tpToPayments(
                            torch.tensor([0 if ii >= i else 1 for ii in range(n)], dtype=torch.float32)
                    )
                )

# %%
def run_dp():
    global decision_offer,decision_welfare,decision_H
    global dp,dp_H,record_ans,utilitya,utilityb
    pdfnumber=[0 for i in range(pdfPrecision+1)];
    cdfnumber=[0 for i in range(pdfPrecision+1)];
    utilitynumber=[0 for i in range(pdfPrecision+1)];
    Possible_utility=[0 for i in range(pdfPrecision+1)];
    utilitya=[0 for i in range(dpPrecision+1)];
    utilityb=[0 for i in range(dpPrecision+1)];
    for i in range(int(trainSize * percentage_train_test)):
        for j in range(n):
            pdfnumber[int(samplesJoint[i,j]*pdfPrecision)]+=1.0/int(trainSize * percentage_train_test*n)
    cdfnumber[0]=pdfnumber[0];
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]
    #print(cdfnumber)  
    for i in range(1,pdfPrecision+1):
        cdfnumber[i]=cdfnumber[i-1]+pdfnumber[i]   
    for i in range(0,pdfPrecision+1):
        utilitynumber[i]=0
        for j in range(i,pdfPrecision+1):
            utilitynumber[i]+=pdfnumber[j]*float(j-i)/pdfPrecision
        if(sum(pdfnumber[i:])!=0):
            utilitynumber[i]/=sum(pdfnumber[i:])
    for i in range(0,dpPrecision):
        ii=int(float(i)/dpPrecision*pdfPrecision)
        jj=int(float(i+1)/dpPrecision*pdfPrecision)
        utilitya[i]=(utilitynumber[jj]-utilitynumber[ii])/dpPrecision
        utilityb[i]=utilitynumber[ii]-utilitya[i]*float(i)/dpPrecision
    plt.plot(pdfnumber)
    plt.show()
    print(sum(pdfnumber))

    plt.plot(utilitynumber)
    plt.show()
    
    
    # howManyPpl left, money left, yes already
    dp        = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1])
    decision_offer = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    decision_welfare = np.zeros([n + 1, dpPrecision + 1, dpPrecision*n + 1], dtype=np.uint8)
    for yes in range(dpPrecision*n + 1):
        for money in range(dpPrecision + 1):
                offer = float(money) / dpPrecision                                                                     
                dp[1, money, yes] =(1.0 - mydistribution.cdf(offer,order).item()) * (yes/dpPrecision + utilitynumber[round(offer*pdfPrecision)])
                decision_offer[1, money, yes] = money
                decision_welfare[1, money, yes] = int(yes + utilitynumber[round(offer*pdfPrecision)]*dpPrecision)
    for ppl in range(2,  n + 1):
        for yes in range(dpPrecision*n + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -100000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        
                        res = (1 - mydistribution.cdf(offer,order)) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order) * (dp[ppl - 1, money, yes])
                    else:
                        yes_old = int(yes+round(utilitynumber[round(offer*pdfPrecision)]*dpPrecision))
                        res = (1 - mydistribution.cdf(offer,order,n-ppl).item()) * dp[
                        ppl - 1, money - offerIndex, min(yes_old, dpPrecision*n)
                        ] + mydistribution.cdf(offer,order,n-ppl).item() * (dp[ppl - 1, money, yes])
                    if maxSoFar < res:
                        maxSoFar = res
                        decision_offer[ppl, money, yes] = offerIndex
                        decision_welfare[ppl, money, yes] = yes_old
                dp[ppl, money, yes] = maxSoFar
    
    print("dp",dp[n, dpPrecision, 0])
    
    def verify_dp(temp,debug):
        if(debug==1):
            print(temp)
        ans =0;
        o_list=[];
        remain_list=[];
        remain=dpPrecision
        record_= 0
        for ppl in range(n,0,-1):
            o=decision_offer[ppl, remain, record_]
            
            #print("record",o,record_)
            if(debug==1):
                print(o,remain,record_)
            o_list.append(o)
            remain_list.append(remain);
            if(o<temp[n-ppl]):
                remain-=int(o);
                record_=decision_welfare[ppl, remain, record_]
                ans=1#+=float(temp[n-ppl]-o)/dpPrecision
                #print("record",record_)
            elif (remain>0):
                ans=0;
        if(remain<=1):
            return ans,o_list;
        else:
            return 0,o_list;
    ans_list=[];
    for i in range(5):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        tempres=verify_dp(temp,1)
        ans_list.append(tempres[0]);
        print(tempres)
        #print("\n",temp)
        #print(plan_dp(temp,1))

    for i in range(10000):
        temp=samplesJoint[i]*dpPrecision
        #print(temp)
        ans_list.append(verify_dp(temp,0)[0]);
        #print("\n",temp)
        #print(plan_dp(temp))
    print("verify dp vaule:",sum(ans_list)/len(ans_list))
    
    # howManyPpl left, money left, yes already
    dp_H = np.zeros([n + 1 , n + 1, dpPrecision + 1])
    decision_H = np.zeros([n + 1 , n + 1, dpPrecision + 1], dtype=np.uint8)
    # ppl = 0 left
    for i in range(1,n+1):
        for money in range(dpPrecision + 1):
            if money == 0:
                dp_H[i, 0, 0] = 1
            else:
                offer = money / dpPrecision
                dp_H[i, 0, money] = 0#mydistribution.cdf(offer)# + 1.0
    for i in range(1,n+1):
        for ppl in range(1, i + 1):
            for money in range(dpPrecision + 1):
                maxSoFar = -1000000
                for offerIndex in range(money + 1):
                    offer = float(offerIndex) / dpPrecision
                    if(order!="independent1" and order!="independent2"):
                        res = (1-mydistribution.cdf(offer,order)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    else:
                        res = (1-mydistribution.cdf(offer,order,ppl-1)) * dp_H[
                         i, ppl - 1, money - offerIndex
                        ]
                    if maxSoFar < res.item():
                        maxSoFar = res.item()
                        decision_H[i, ppl, money] = offerIndex
                dp_H[i, ppl, money] = maxSoFar

# %%
def init_weights_xavier_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
def init_weights_xavier_normal(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_uniform(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_uniform_(m.weight)
        m.bias.data.fill_(0.1)
        
        
def init_weights_kaiming_normal_(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.1)

# %%
for order in stage:
    samplesJoint=mydistribution.producedata(order,trainSize)
    tp_tensor = torch.tensor(samplesJoint, dtype=torch.float32)
    tp_dataset = TensorDataset(tp_tensor[: int(trainSize * percentage_train_test)])
    tp_dataset_testing = TensorDataset(tp_tensor[int(trainSize * (1.0-percentage_train_test)) :])
    tp_dataloader = DataLoader(tp_dataset, batch_size=128, shuffle=True)
    tp_dataloader_testing = DataLoader(tp_dataset_testing, batch_size=256, shuffle=False)
    run_dp()
    #running
    for order1 in order1name:
        print("Supervised Aim:",order,order1)
        
        # Instantiate the model with hyperparameters
        model = nn.Sequential(
            nn.Linear(n, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, 100),
            nn.ReLU(),
            nn.Linear(100, n),
        )
        if(init_weights=="xavier_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="xavier_normal"):
            model.apply(init_weights_xavier_normal)
        if(init_weights=="kaiming_uniform"):
            model.apply(init_weights_xavier_uniform)
        if(init_weights=="kaiming_normal"):
            model.apply(init_weights_xavier_normal)
        # optimizer = optim.SGD(model.parameters(), lr=lr)
        optimizer = optim.Adam(model.parameters(), lr=lr1)
        print(model)
        
        runningLossNN = []
        runningLossCS = []
        runningLossDP = []
        runningLossHeuristic = []
        #model=torch.load("save/pytorchNN=5dp1");
        #model.eval()
        ##order1name=["costsharing","dp","heuristic","random initializing"]
        for epoch in range(1, supervisionEpochs + 1):
#             print("distributionRatio",distributionRatio)
            if(order1=="costsharing"):
                supervisionTrain(epoch, costSharingSupervisionRule)
            elif(order1=="dp"):
                supervisionTrain(epoch, dpSupervisionRule)
            elif(order1=="heuristic"):
                supervisionTrain(epoch, heuristicSupervisionRule)
            elif(order1=="random initializing"):
                print("do nothing");

        test()
        optimizer = optim.Adam(model.parameters(), lr=lr2)
        for epoch in range(1, epochs + 1):
            train(epoch)
            test()
        losslistname.append(order+" "+order1);
        losslist.append(losslisttemp);
        losslisttemp=[];
        savepath="save/pytorchNN=5all-beta"+order+str(order1)
        torch.save(model, savepath);
        print("end")
        print()
# Out:
# loc 0.15 scale 0.1
# loc 0.85 scale 0.1
# 0.9999999999999719
# dp 1.2881019115447998
# [47.80497546 18.50575103 34.81823066 38.84318644  6.04197214]
# 32 50 0
# 8 18 24
# 8 10 47
# 2 2 71
# 0 0 96
# (1, [32, 8, 8, 2, 0])
# [11.18809346 47.70758678 10.97584868  0.89959125 42.86138213]
# 32 50 0
# 32 50 0
# 10 18 24
# 8 8 47
# 8 8 47
# (1, [32, 32, 10, 8, 8])
# [11.16741025  7.93406654 36.6309047  44.40520749  2.88371565]
# 32 50 0
# 32 50 0
# 22 50 0
# 28 28 16
# 0 0 41
# (1, [32, 32, 22, 28, 0])
# [ 0.03977706  8.09981415  4.68649759 10.03224169  9.44231796]
# 32 50 0
# 32 50 0
# 22 50 0
# 22 50 0
# 50 50 0
# (0, [32, 32, 22, 22, 50])
# [ 4.44110765  2.22702952 38.5402559  41.06530539  2.4332712 ]
# 32 50 0
# 32 50 0
# 22 50 0
# 28 28 16
# 0 0 41
# (1, [32, 32, 22, 28, 0])
# verify dp vaule: 0.8183908045977012
# Supervised Aim: twopeak dp
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.041335
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.001094
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000098
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000018
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000012
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000012
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000010
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:105: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:108: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NN 1 : tensor(1.2985)
# CS 1 : 1.2336931584894657
# DP 1 : 1.2873156263649463
# heuristic 1 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([6.3567e-01, 1.6088e-01, 1.6275e-01, 4.0651e-02, 4.7419e-05])
# tensor([0.6333, 0.1591, 0.1604, 0.0471, 1.0000])
# tensor([0.6430, 0.1606, 0.1963, 1.0000, 1.0000])
# tensor([0.8070, 0.1930, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 52.169994 testing loss: tensor(1.2985)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 46.601128 testing loss: tensor(1.2987)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 41.603348 testing loss: tensor(1.2986)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 36.185318 testing loss: tensor(1.2986)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 31.315115 testing loss: tensor(1.2982)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 25.902481 testing loss: tensor(1.2980)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 20.778332 testing loss: tensor(1.2979)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 15.617010 testing loss: tensor(1.2980)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 10.877038 testing loss: tensor(1.2979)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 5.273473 testing loss: tensor(1.2978)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 2.927454 testing loss: tensor(1.2977)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 2.965461 testing loss: tensor(1.2977)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 2.947575 testing loss: tensor(1.2977)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 2.850102 testing loss: tensor(1.2977)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 2.799838 testing loss: tensor(1.2977)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 3.132086 testing loss: tensor(1.2977)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 2.800665 testing loss: tensor(1.2976)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 2.776410 testing loss: tensor(1.2976)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 2.640152 testing loss: tensor(1.2976)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 2.697524 testing loss: tensor(1.2976)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 2.693217 testing loss: tensor(1.2976)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 2.599240 testing loss: tensor(1.2976)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 2.785481 testing loss: tensor(1.2977)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 2.421850 testing loss: tensor(1.2977)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 2.713622 testing loss: tensor(1.2977)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 2.653594 testing loss: tensor(1.2978)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 2.596957 testing loss: tensor(1.2977)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 2.690601 testing loss: tensor(1.2977)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 2.567048 testing loss: tensor(1.2977)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 2.615830 testing loss: tensor(1.2978)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 2.549598 testing loss: tensor(1.2978)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 2.448910 testing loss: tensor(1.2978)
# penalty: 0.004480376839637756
# NN 2 : tensor(1.2978)
# CS 2 : 1.2336931584894657
# DP 2 : 1.2873156263649463
# heuristic 2 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([6.4634e-01, 1.5372e-01, 1.6508e-01, 3.4832e-02, 3.5041e-05])
# tensor([0.6463, 0.1533, 0.1610, 0.0393, 1.0000])
# tensor([0.6492, 0.1556, 0.1952, 1.0000, 1.0000])
# tensor([0.8120, 0.1880, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak random initializing
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# do nothing
# NN 1 : tensor(1.2437)
# CS 1 : 1.2336931584894657
# DP 1 : 1.2873156263649463
# heuristic 1 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([0.1612, 0.2685, 0.2105, 0.2005, 0.1594])
# tensor([0.1938, 0.3248, 0.2448, 0.2366, 1.0000])
# tensor([0.2262, 0.4945, 0.2792, 1.0000, 1.0000])
# tensor([0.3819, 0.6181, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.917354 testing loss: tensor(1.2437)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 0.677808 testing loss: tensor(1.2445)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 1.065408 testing loss: tensor(1.2449)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 0.650705 testing loss: tensor(1.2457)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 0.813096 testing loss: tensor(1.2464)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.984683 testing loss: tensor(1.2475)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 0.943370 testing loss: tensor(1.2482)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 0.786381 testing loss: tensor(1.2494)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 0.590889 testing loss: tensor(1.2509)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 0.395650 testing loss: tensor(1.2526)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.719511 testing loss: tensor(1.2539)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 1.176883 testing loss: tensor(1.2558)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 0.885932 testing loss: tensor(1.2573)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 0.873847 testing loss: tensor(1.2591)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 0.379005 testing loss: tensor(1.2610)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.279765 testing loss: tensor(1.2626)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 0.426759 testing loss: tensor(1.2647)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 0.602489 testing loss: tensor(1.2672)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 0.655990 testing loss: tensor(1.2684)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 0.393393 testing loss: tensor(1.2700)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.432374 testing loss: tensor(1.2718)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 0.753647 testing loss: tensor(1.2740)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 0.376735 testing loss: tensor(1.2758)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 0.311951 testing loss: tensor(1.2764)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 0.506183 testing loss: tensor(1.2766)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.443484 testing loss: tensor(1.2767)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 0.596335 testing loss: tensor(1.2767)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 0.758371 testing loss: tensor(1.2768)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 0.529220 testing loss: tensor(1.2769)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 0.347333 testing loss: tensor(1.2771)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.935877 testing loss: tensor(1.2774)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 0.559241 testing loss: tensor(1.2775)
# penalty: 0.0
# NN 2 : tensor(1.2775)
# CS 2 : 1.2336931584894657
# DP 2 : 1.2873156263649463
# heuristic 2 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([0.1051, 0.4520, 0.1501, 0.1890, 0.1037])
# tensor([0.1184, 0.5041, 0.1696, 0.2079, 1.0000])
# tensor([0.1358, 0.6757, 0.1886, 1.0000, 1.0000])
# tensor([0.2235, 0.7765, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak costsharing
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.001032
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.000013
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000001
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000000
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000000
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000000
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000000
# NN 1 : tensor(1.2337)
# CS 1 : 1.2336931584894657
# DP 1 : 1.2873156263649463
# heuristic 1 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([0.1999, 0.2001, 0.2000, 0.2000, 0.2000])
# tensor([0.2495, 0.2503, 0.2505, 0.2498, 1.0000])
# tensor([0.3333, 0.3332, 0.3335, 1.0000, 1.0000])
# tensor([0.5000, 0.5000, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 1.114190 testing loss: tensor(1.2337)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 1.117265 testing loss: tensor(1.2337)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 0.853236 testing loss: tensor(1.2336)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 0.824662 testing loss: tensor(1.2336)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 0.843236 testing loss: tensor(1.2336)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.974185 testing loss: tensor(1.2336)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 1.138192 testing loss: tensor(1.2336)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 1.083234 testing loss: tensor(1.2337)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 1.246508 testing loss: tensor(1.2336)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 1.129783 testing loss: tensor(1.2335)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.858952 testing loss: tensor(1.2335)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 0.636003 testing loss: tensor(1.2335)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 0.935267 testing loss: tensor(1.2335)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 0.657507 testing loss: tensor(1.2335)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 1.005704 testing loss: tensor(1.2336)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 1.125337 testing loss: tensor(1.2336)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 0.618176 testing loss: tensor(1.2336)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 1.222358 testing loss: tensor(1.2336)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 0.897114 testing loss: tensor(1.2336)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 0.685912 testing loss: tensor(1.2336)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 1.155155 testing loss: tensor(1.2336)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 1.210312 testing loss: tensor(1.2336)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 0.884170 testing loss: tensor(1.2336)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 0.719139 testing loss: tensor(1.2336)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 0.803321 testing loss: tensor(1.2337)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.838511 testing loss: tensor(1.2336)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 0.744870 testing loss: tensor(1.2336)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 0.819317 testing loss: tensor(1.2336)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 0.761315 testing loss: tensor(1.2336)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 1.036208 testing loss: tensor(1.2336)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 1.035244 testing loss: tensor(1.2336)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 0.973911 testing loss: tensor(1.2336)
# penalty: 0.0
# NN 2 : tensor(1.2336)
# CS 2 : 1.2336931584894657
# DP 2 : 1.2873156263649463
# heuristic 2 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([0.1998, 0.2020, 0.1993, 0.1997, 0.1992])
# tensor([0.2491, 0.2521, 0.2495, 0.2493, 1.0000])
# tensor([0.3326, 0.3354, 0.3320, 1.0000, 1.0000])
# tensor([0.4977, 0.5023, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end
#
# Supervised Aim: twopeak heuristic
# Sequential(
#   (0): Linear(in_features=5, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=5, bias=True)
# )
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.040898
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 0.001102
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 0.000256
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 0.000244
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 0.000140
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 0.000094
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 0.000089
# NN 1 : tensor(1.2922)
# CS 1 : 1.2336931584894657
# DP 1 : 1.2873156263649463
# heuristic 1 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([0.0564, 0.0754, 0.0768, 0.0809, 0.7105])
# tensor([0.0772, 0.0979, 0.0998, 0.7251, 1.0000])
# tensor([0.1212, 0.1402, 0.7386, 1.0000, 1.0000])
# tensor([0.5013, 0.4987, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# Train Epoch: 1 [0/20000 (0%)]	Loss: 819.139465 testing loss: tensor(1.2929)
# Train Epoch: 1 [640/20000 (3%)]	Loss: 807.458069 testing loss: tensor(1.2950)
# Train Epoch: 1 [1280/20000 (6%)]	Loss: 795.474670 testing loss: tensor(1.2970)
# Train Epoch: 1 [1920/20000 (10%)]	Loss: 784.224731 testing loss: tensor(1.2985)
# Train Epoch: 1 [2560/20000 (13%)]	Loss: 772.513733 testing loss: tensor(1.3000)
# Train Epoch: 1 [3200/20000 (16%)]	Loss: 761.302856 testing loss: tensor(1.3016)
# Train Epoch: 1 [3840/20000 (19%)]	Loss: 749.751526 testing loss: tensor(1.3029)
# Train Epoch: 1 [4480/20000 (22%)]	Loss: 738.795837 testing loss: tensor(1.3041)
# Train Epoch: 1 [5120/20000 (25%)]	Loss: 727.801270 testing loss: tensor(1.3052)
# Train Epoch: 1 [5760/20000 (29%)]	Loss: 716.052063 testing loss: tensor(1.3059)
# Train Epoch: 1 [6400/20000 (32%)]	Loss: 704.447937 testing loss: tensor(1.3064)
# Train Epoch: 1 [7040/20000 (35%)]	Loss: 693.226379 testing loss: tensor(1.3074)
# Train Epoch: 1 [7680/20000 (38%)]	Loss: 681.775452 testing loss: tensor(1.3080)
# Train Epoch: 1 [8320/20000 (41%)]	Loss: 670.338013 testing loss: tensor(1.3089)
# Train Epoch: 1 [8960/20000 (45%)]	Loss: 658.453491 testing loss: tensor(1.3097)
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 646.294128 testing loss: tensor(1.3105)
# Train Epoch: 1 [10240/20000 (51%)]	Loss: 633.820312 testing loss: tensor(1.3109)
# Train Epoch: 1 [10880/20000 (54%)]	Loss: 620.856262 testing loss: tensor(1.3112)
# Train Epoch: 1 [11520/20000 (57%)]	Loss: 608.257629 testing loss: tensor(1.3116)
# Train Epoch: 1 [12160/20000 (61%)]	Loss: 595.208374 testing loss: tensor(1.3118)
# Train Epoch: 1 [12800/20000 (64%)]	Loss: 582.073425 testing loss: tensor(1.3122)
# Train Epoch: 1 [13440/20000 (67%)]	Loss: 568.616089 testing loss: tensor(1.3125)
# Train Epoch: 1 [14080/20000 (70%)]	Loss: 555.456055 testing loss: tensor(1.3125)
# Train Epoch: 1 [14720/20000 (73%)]	Loss: 541.478943 testing loss: tensor(1.3125)
# Train Epoch: 1 [15360/20000 (76%)]	Loss: 527.649048 testing loss: tensor(1.3126)
# Train Epoch: 1 [16000/20000 (80%)]	Loss: 514.101501 testing loss: tensor(1.3128)
# Train Epoch: 1 [16640/20000 (83%)]	Loss: 500.052002 testing loss: tensor(1.3125)
# Train Epoch: 1 [17280/20000 (86%)]	Loss: 486.002350 testing loss: tensor(1.3125)
# Train Epoch: 1 [17920/20000 (89%)]	Loss: 472.067810 testing loss: tensor(1.3123)
# Train Epoch: 1 [18560/20000 (92%)]	Loss: 458.057648 testing loss: tensor(1.3122)
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 443.757477 testing loss: tensor(1.3119)
# Train Epoch: 1 [19840/20000 (99%)]	Loss: 429.587097 testing loss: tensor(1.3117)
# penalty: 0.8529285788536072
# NN 2 : tensor(1.3116)
# CS 2 : 1.2336931584894657
# DP 2 : 1.2873156263649463
# heuristic 2 : 1.282708691084385
# DP: 1.2881019115447998
# tensor([0.0587, 0.0789, 0.0789, 0.0809, 0.7026])
# tensor([0.1106, 0.1514, 0.1420, 0.5960, 1.0000])
# tensor([0.1637, 0.1966, 0.6398, 1.0000, 1.0000])
# tensor([0.4901, 0.5099, 1.0000, 1.0000, 1.0000])
# tensor([1., 1., 1., 1., 1.])
# end

# %%
colorlist=["#D2691E",'#4169E1',"#9ACD32","#B22222","#FF00FF","#708090"]
for i in range(len(losslist)):
    plt.plot(losslist[i], '.-', color=colorlist[i], alpha=0.8, label=losslistname[i])

# 显示标签，如果不加这句，即使加了label='一些数字'的参数，最终还是不会显示标签
plt.legend(loc="best")
plt.xlabel('Trianing Times')
plt.ylabel('Welfare')

plt.show()
