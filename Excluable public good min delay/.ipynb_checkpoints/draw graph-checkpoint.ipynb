# %%
import matplotlib.pyplot as plt
import copy

# %%
NN_dp3=[1.4413,1.4402,1.4455,1.4427,1.4397,1.4402,1.4390,1.4375,1.4363,1.4369,1.4361,1.4344,1.4345,1.4340,1.4343,
      1.4328,1.4327,1.4340,1.4349,1.4327,1.4326,1.4324,1.4318,1.4303,1.4308,1.4303,1.4325,1.4323,1.4307,1.4312,1.4309,
      1.4311,1.4313,1.4299,1.4295,1.4296,1.4300,1.4286,1.4285,1.4298,1.4272,1.4267,1.4263,1.4271,1.4265,1.4272,1.4258,1.4261]

# %%
NN_dp=[1.4346, 1.4387,1.4426,1.4313,1.4285,1.4266,1.4268,1.4264,1.4257,1.4246,
      1.4256,1.4238,1.4244,1.4246,1.4250,1.4229,1.4220,1.4206,1.4224,1.4197,
      1.4199,1.4186,1.4192,1.4184,1.4180,1.4176,1.4172,1.4166,1.4161,1.4165,
      1.4156,1.4160,1.4158,1.4152,1.4144,1.4153,1.4145,1.4138,1.4128,1.4144,
      1.4144,1.4133,1.4137,1.4138,1.4126,1.4138,1.4127,1.4129]

# %%
print(len(NN_dp))
NN_dp2= copy.deepcopy(NN_dp)
for i in range(len(NN_dp2)):
    NN_dp2[i]=NN_dp2[i]-0.1
# Out:
# 48

# %%
plt.plot(NN_dp)
plt.plot(NN_dp2)

# %%
colorlist=["#D2691E",'#4169E1',"#9ACD32","#B22222","#FF00FF","#708090"]
losslist=[NN_dp]
print(NN_dp)
for i in range(len(losslist)):
    plt.plot(losslist[i], '.-', color=colorlist[i], alpha=0.8)

plt.show()
# Out:
# [1.4346, 1.4387, 1.4426, 1.4313, 1.4285, 1.4266, 1.4268, 1.4264, 1.4257, 1.4246, 1.4256, 1.4238, 1.4244, 1.4246, 1.425, 1.4229, 1.422, 1.4206, 1.4224, 1.4197, 1.4199, 1.4186, 1.4192, 1.4184, 1.418, 1.4176, 1.4172, 1.4166, 1.4161, 1.4165, 1.4156, 1.416, 1.4158, 1.4152, 1.4144, 1.4153, 1.4145, 1.4138, 1.4128, 1.4144, 1.4144, 1.4133, 1.4137, 1.4138, 1.4126, 1.4138, 1.4127, 1.4129]
